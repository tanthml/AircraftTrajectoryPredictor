# %% [markdown]
# ## Tutorial Notebook

# %% [markdown]
# In this notebook, we demonstrate how to generate trajectory of aircraft using BADA model.
#
# The notebook includes 3 steps:
#
# 1. Generate the whole trajectory
# 2. Generate state vectors of aircraft at every waypoints in the flight plan
# 3. Generate trajectory from a waypoint to the end of the flight plan

# %%
# !pip install xlsxwriter xlrd
# Out:
# Requirement already satisfied: xlsxwriter in /home/tanthm/git/atm-research/venv/lib/python3.7/site-packages (1.2.7)
# Requirement already satisfied: xlrd in /home/tanthm/git/atm-research/venv/lib/python3.7/site-packages (1.2.0)

# %%
from Home.Guidance.FlightPathFile import FlightPath
# Out:
# BadaAircraftDatabase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance
# BadaAircraftDatabase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/SYNONYM.NEW
# BadaAircraftDatabase: opening file=  /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/SYNONYM.NEW
# BadaAircraftDatabase: number of aircrafts in db= 322

# %%
# put these pieces of code to convert between different measurement 
Meter2Feet = 3.2808 # one meter equals 3.28 feet
Meter2NauticalMiles = 0.000539956803 # One Meter = 0.0005 nautical miles
NauticalMiles2Meter = 1852
Knots2MetersPerSecond = 0.514444444

# %% [markdown]
# ### 0. General configurations

# %% [markdown]
# #### Construct the strRoute
# The string route use 'ADEP' and 'ADES' to denote for departure and arrival airport
#
# StrRoute = 'ADEP'/'AirportICAOcode'/'Runway'-List-of-waypoints-in-flight-plan-'ADES'/'AirportICAOcode'/'Runway'
#
# #### Input airport and runway information
#
# All the information of the airport are stored in. /AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/Environment/Runways.csv
#
# #### Input waypoint information
#
# All the information of the waypoint are stored in. /AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/Environment/Waypoints.csv
#
# #### Link to find the information of runway airport
#
# https://skyvector.com/airport/WSSS/Singapore-Changi-International-Airport
#
# #### Link to read the kml file
#
# http://ivanrublev.me/kml/

# %% [markdown]
# ### 1. Generate the whole trajectory

# %% [markdown]
# #### Input:
# strRoute: the full flight plan
#
# aircraftICAOcode: type of aircraft
#
# RequestedFlightLevel: Level of cruise phase
#
# WindSpeedMetersPerSecond: wind speed m/s
#
# windDirectionDegrees: direction of wind
#
# #### Output
#
# Generate the whole trajectory and save in a .xlsx file in ./ResultsFiles/ folder
#
# Generate the whole trajectory and save in a .kml file in ./ResultsFiles/ folder

# %%
# configuration
strRoute = 'ADEP/LFPG/26R-LAIGLE-ROLEN-PEPON-KURIS-TERPO-ERIGA-INBAB-ATLEN-DEVAR-ASTURIAS-KUVAN-BISMU-BARKO-FATIMA-ADES/LPPT/03'
flightPath = FlightPath(route = strRoute,
                        aircraftICAOcode = 'A320',
                        RequestedFlightLevel = 330,
                        cruiseMach = 0.82,
                        takeOffMassKilograms = 68000.0,
                        windSpeedMetersPerSecond=25* Knots2MetersPerSecond,
                        windDirectionDegrees=25)

# If we want to generate the whole flight, use the .computeFlight function
flightPath.computeFlight(deltaTimeSeconds = 1.0)
flightPath.createFlightOutputFiles()
# Out:
# FlightPath: route= ADEP/LFPG/26R-LAIGLE-ROLEN-PEPON-KURIS-TERPO-ERIGA-INBAB-ATLEN-DEVAR-ASTURIAS-KUVAN-BISMU-BARKO-FATIMA-ADES/LPPT/03
# WayPointsDatabase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# WayPointsDatabase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/WayPoints.xls
# AirportsDatabase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# AirportsDatabase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/Airports.csv
# RunWayDataBase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# RunWayDataBase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/RunWays.xls
# /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/RunWays.xls
# FlightPath: departure airport= Airport: Airport: LFPG - France - Paris-Charles De Gaulle - lat= 49.01 degrees - long= 2.55 degrees - field elevation= 119.48 meters
# FlightPath: departure runway= RunWay: runway= 26R airport ICAO code= LFPG length= 13829.00 feet true heading= 265.00 degrees latitude= 49.00 degrees longitude= 2.61 degrees
# FlightPath: arrival airport= Airport: Airport: LPPT - Portugal - Lisbon-Lisboa - lat= 38.78 degrees - long= -9.14 degrees - field elevation= 114.00 meters
# FlightPath: arrival runway= RunWay: runway= 03 airport ICAO code= LPPT length= 12484.00 feet true heading= 22.00 degrees latitude= 38.77 degrees longitude= -9.14 degrees
# FlightPath: fix= LAIGLE
# FlightPath============ index = 0 ===========
# FlightPath: fix= ROLEN
# Airport: Airport: LFPG - France - Paris-Charles De Gaulle - lat= 49.01 degrees - long= 2.55 degrees - field elevation= 119.48 meters
# LAIGLE - latitude= 48.79 degrees - longitude= 0.53 degrees - altitudeMSL= 0.00 meters
# ROLEN - latitude= 48.58 degrees - longitude= 0.16 degrees - altitudeMSL= 0.00 meters
# FlightPath: Paris-Charles De Gaulle - LAIGLE - ROLEN
# FlightPath: first angle= 261.26 degrees and second angle= 229.66 degrees
# FlightPath: difference= -31.61 degrees
# FlightPath: WARNING - angle difference=  -31.61 greater to 30.00 degrees
# FlightPath============ index = 1 ===========
# FlightPath: fix= PEPON
# LAIGLE - latitude= 48.79 degrees - longitude= 0.53 degrees - altitudeMSL= 0.00 meters
# ROLEN - latitude= 48.58 degrees - longitude= 0.16 degrees - altitudeMSL= 0.00 meters
# PEPON - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 0.00 meters
# FlightPath: LAIGLE - ROLEN - PEPON
# FlightPath: first angle= 229.66 degrees and second angle= 229.69 degrees
# FlightPath: difference= 0.03 degrees
# FlightPath: WARNING - distance between LAIGLE and ROLEN less than 20 Nm = 19.50
# FlightPath============ index = 2 ===========
# FlightPath: fix= KURIS
# ROLEN - latitude= 48.58 degrees - longitude= 0.16 degrees - altitudeMSL= 0.00 meters
# PEPON - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 0.00 meters
# KURIS - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 0.00 meters
# FlightPath: ROLEN - PEPON - KURIS
# FlightPath: first angle= 229.69 degrees and second angle= 228.99 degrees
# FlightPath: difference= -0.70 degrees
# FlightPath============ index = 3 ===========
# FlightPath: fix= TERPO
# PEPON - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 0.00 meters
# KURIS - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 0.00 meters
# TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 0.00 meters
# FlightPath: PEPON - KURIS - TERPO
# FlightPath: first angle= 228.99 degrees and second angle= 228.10 degrees
# FlightPath: difference= -0.89 degrees
# FlightPath============ index = 4 ===========
# FlightPath: fix= ERIGA
# KURIS - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 0.00 meters
# TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 0.00 meters
# ERIGA - latitude= 46.86 degrees - longitude= -2.36 degrees - altitudeMSL= 0.00 meters
# FlightPath: KURIS - TERPO - ERIGA
# FlightPath: first angle= 228.10 degrees and second angle= 211.31 degrees
# FlightPath: difference= -16.79 degrees
# FlightPath============ index = 5 ===========
# FlightPath: fix= INBAB
# TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 0.00 meters
# ERIGA - latitude= 46.86 degrees - longitude= -2.36 degrees - altitudeMSL= 0.00 meters
# INBAB - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 0.00 meters
# FlightPath: TERPO - ERIGA - INBAB
# FlightPath: first angle= 211.31 degrees and second angle= 218.42 degrees
# FlightPath: difference= 7.11 degrees
# FlightPath============ index = 6 ===========
# FlightPath: fix= ATLEN
# ERIGA - latitude= 46.86 degrees - longitude= -2.36 degrees - altitudeMSL= 0.00 meters
# INBAB - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 0.00 meters
# ATLEN - latitude= 44.51 degrees - longitude= -4.95 degrees - altitudeMSL= 0.00 meters
# FlightPath: ERIGA - INBAB - ATLEN
# FlightPath: first angle= 218.42 degrees and second angle= 217.36 degrees
# FlightPath: difference= -1.05 degrees
# FlightPath============ index = 7 ===========
# FlightPath: fix= DEVAR
# INBAB - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 0.00 meters
# ATLEN - latitude= 44.51 degrees - longitude= -4.95 degrees - altitudeMSL= 0.00 meters
# DEVAR - latitude= 43.94 degrees - longitude= -5.57 degrees - altitudeMSL= 0.00 meters
# FlightPath: INBAB - ATLEN - DEVAR
# FlightPath: first angle= 217.36 degrees and second angle= 218.80 degrees
# FlightPath: difference= 1.44 degrees
# FlightPath============ index = 8 ===========
# FlightPath: fix= ASTURIAS
# ATLEN - latitude= 44.51 degrees - longitude= -4.95 degrees - altitudeMSL= 0.00 meters
# DEVAR - latitude= 43.94 degrees - longitude= -5.57 degrees - altitudeMSL= 0.00 meters
# ASTURIAS - latitude= 43.56 degrees - longitude= -6.01 degrees - altitudeMSL= 0.00 meters
# FlightPath: ATLEN - DEVAR - ASTURIAS
# FlightPath: first angle= 218.80 degrees and second angle= 219.20 degrees
# FlightPath: difference= 0.40 degrees
# FlightPath============ index = 9 ===========
# FlightPath: fix= KUVAN
# DEVAR - latitude= 43.94 degrees - longitude= -5.57 degrees - altitudeMSL= 0.00 meters
# ASTURIAS - latitude= 43.56 degrees - longitude= -6.01 degrees - altitudeMSL= 0.00 meters
# KUVAN - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 0.00 meters
# FlightPath: DEVAR - ASTURIAS - KUVAN
# FlightPath: first angle= 219.20 degrees and second angle= 206.92 degrees
# FlightPath: difference= -12.29 degrees
# FlightPath============ index = 10 ===========
# FlightPath: fix= BISMU
# ASTURIAS - latitude= 43.56 degrees - longitude= -6.01 degrees - altitudeMSL= 0.00 meters
# KUVAN - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 0.00 meters
# BISMU - latitude= 42.80 degrees - longitude= -6.54 degrees - altitudeMSL= 0.00 meters
# FlightPath: ASTURIAS - KUVAN - BISMU
# FlightPath: first angle= 206.92 degrees and second angle= 207.36 degrees
# FlightPath: difference= 0.44 degrees
# FlightPath============ index = 11 ===========
# FlightPath: fix= BARKO
# KUVAN - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 0.00 meters
# BISMU - latitude= 42.80 degrees - longitude= -6.54 degrees - altitudeMSL= 0.00 meters
# BARKO - latitude= 42.20 degrees - longitude= -6.94 degrees - altitudeMSL= 0.00 meters
# FlightPath: KUVAN - BISMU - BARKO
# FlightPath: first angle= 207.36 degrees and second angle= 206.81 degrees
# FlightPath: difference= -0.54 degrees
# FlightPath============ index = 12 ===========
# FlightPath: fix= FATIMA
# BISMU - latitude= 42.80 degrees - longitude= -6.54 degrees - altitudeMSL= 0.00 meters
# BARKO - latitude= 42.20 degrees - longitude= -6.94 degrees - altitudeMSL= 0.00 meters
# FATIMA - latitude= 39.67 degrees - longitude= -8.49 degrees - altitudeMSL= 0.00 meters
# FlightPath: BISMU - BARKO - FATIMA
# FlightPath: first angle= 206.81 degrees and second angle= 205.28 degrees
# FlightPath: difference= -1.53 degrees
# FlightPath============ index = 13 ===========
# 1515461.6199379596
# FlightPath: ================ get aircraft =================
# BadaAircraftDatabase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance
# BadaAircraftDatabase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/SYNONYM.NEW
# BadaAircraftDatabase: opening file=  /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/SYNONYM.NEW
# BadaAircraftDatabase: number of aircrafts in db= 322
# BadaAircraftDatabase: aircraft= A320 exists= True
# BadaAircraftDatabase: aircraft= A320 - found in database
# BadaAircraftDatabase: aircraft= A320 - OPF file= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/../Bada381DataFiles/A320__.OPF - exists= True
# FlightPath: performance file= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/../Bada381DataFiles/A320__.OPF
# BadaAircraft: Wing Area Surface= 122.6 Square-Meters
# BadaAircraft: stall speed= {'CR': 145.0, 'IC': 120.0, 'TO': 114.0, 'AP': 107.0, 'LD': 101.0} knots
# AircraftMass: aircraft reference mass= 64000.00 kilograms
# AircraftMass: aircraft minimum mass= 39000.00 kilograms
# AircraftMass: aircraft maximum mass= 77000.00 kilograms
# AircraftMass: aircraft maximum pay load mass= 21500.00 kilograms
# BadaAircraft: ===================================================
# BadaAircraft: default configuration= departure-ground-run
# BadaAircraft: ===================================================
# BadaAircraft: transition altitude= 24547.67 feet
# BadaAircraft ICAO code= A320
# BadaAircraft aircraft full name= AIRBUS-A320
# AircraftMass ==========================================================
# AircraftMass: set Aircraft Mass= 68000.00 kilograms - Mass= 149914.34 pounds
# AircraftMass ==========================================================
# BadaAircraft: set Cruise FL= 330 - QNH= 999.25 hecto Pascals - computed Altitude MSL=  10058.40 meters
# 0.82
# BadaAircraft====================================================
# BadaAircraft: set target cruise Mach= 0.82
# BadaAircraft====================================================
# FlightPath ============== build the departure ground run ===========
# GroundRunLeg: ground run - run-way true heading= 265.0 degrees
# GroundRunLeg: V stall Calibrated AirSpeed= 117.51 knots
# BadaAircraft: TAS= 143.93 knots - CAS= 143.17 knots > (1.2 * V CAS stall)= 140.94 knots
# BadaAircraft ====================================
# BadaAircraft: entering take-off configuration - distance flown 1667.38 meters - distance flown 0.90 nautics
# BadaAircraft: alt= 119.48 meters alt= 392.00 feet
# BadaAircraft: tas= 72.53 m/s - tas= 141.00 knots - cas= 72.15 m/s - cas= 140.25 knots - mach= 0.21
# BadaAircraft: real time = 45.00 seconds - 0.00 hours 0.00 minutes 45.00 seconds
# BadaAircraft ====================================
# ClimbRamp: run-way orientation degrees= 265.0 degrees
# BadaAircraft: CAS= 145.24 knots >= Initial Climb Stall Speed= 123.62 knots
# BadaAircraft ====================================
# BadaAircraft: entering initial-climb configuration - distance flown 2187.44 meters - distance flown 1.18 nautics
# BadaAircraft: alt= 165.85 meters alt= 544.12 feet
# BadaAircraft: tas= 75.12 m/s - tas= 146.02 knots - cas= 74.57 m/s - cas= 144.95 knots - mach= 0.22
# BadaAircraft: real time = 52.00 seconds - 0.00 hours 0.00 minutes 52.00 seconds
# BadaAircraft ====================================
# FlightPath: last leg orientation= 265.00 degrees
# 265.00000000029854 climb-ramp-pt-111-9289.12-meters - latitude= 48.99 degrees - longitude= 2.46 degrees - altitudeMSL= 1098.12 meters
# FlightPath=========== add final turn, descent and ground run ===================
# GroundRunLeg: ground run - run-way true heading= 22.0 degrees
# ArrivalRunWayTouchDownConstraint: add touch down constraint= Lisbon-Lisboa-Rwy-03-touch-down - latitude= 38.78 degrees - longitude= -9.14 degrees - altitudeMSL= 114.00 meters
# Lisbon-Lisboa-Rwy-03-touch-down - latitude= 38.78 degrees - longitude= -9.14 degrees - altitudeMSL= 114.00 meters
# FlightPath===================== final 3 degrees descending glide slope ================
# DescentGlideSlope: airport field Elevation Above Sea Level= 114.00 meters
# DescentGlideSlope: distance from RunWay - TouchDown to RunWay - End= 1440.000000000747 meters
# DescentGlideSlope: bearing from touch-down to runway end= 202.00 degrees
# DescentGlideSlope: glide slope Length= 9260.0  meters
# DescentGlideSlope: glide slope orientation= 22.0 degrees
# DescentGlideSlope: distance from last way point to touch-down: 5.00 nautics
# FlightPath: top of arrival glide slope= glide-slope-pt-99-9260.000000000016-meters - latitude= 38.85 degrees - longitude= -9.10 degrees - altitudeMSL= 599.29 meters
# FlightPath ================= need a turn leg to find the junction point the last way-point in the fix list to the top of the final glide slope
# TurnLeg: turn from= 22.00 degrees  to 30.23 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 113.29 knots - radius of turn= 3957.46 meters - radius of turn= 2.14 nautics
# TurnLeg: initial heading= 22.00 degrees
# FlightPath: begin of last turn= turn-pt-9-30.44-degrees - latitude= 38.86 degrees - longitude= -9.10 degrees - altitudeMSL= 599.29 meters
# TargetApproachConstraint: add target approach way point constraint= turn-pt-9-30.44-degrees - latitude= 38.86 degrees - longitude= -9.10 degrees - altitudeMSL= 599.29 meters
# FlightPath: updated flight path length= 828.91 nautics
# FlightPath: fix list= ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees']
# 1535145.3027293202
# fix, tailWayPoint:  0 16 climb-ramp-pt-111-9289.12-meters climb-ramp-pt-111-9289.12-meters - latitude= 48.99 degrees - longitude= 2.46 degrees - altitudeMSL= 1098.12 meters
# LAIGLE - latitude= 48.79 degrees - longitude= 0.53 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 265.00 degrees  to 261.79 degrees - turn step is= -3.00 degrees
# FlightPath: distance to last fix= 809.5329156948146 nautics
# FlightPath: still to fly= 822.95612939417 nautics
# TurnLeg: tas= 183.03 knots - radius of turn= 3372.81 meters - radius of turn= 1.82 nautics
# TurnLeg: initial heading= 265.00 degrees
# TurnLeg: final heading= 260.21 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 260.21 degrees
# FlightPath: difference= -32.13 degrees
# FlightPath: anticipated turn start from end point= 11848.34 meters
# FlightPath: Envisage anticipated Fly By turn !!!!!!!!!!!!!!!!!!!!!!!!!
#  ==================== great circle ========================
# FlightPath: distance to last fix= 809.3806892024462 nautics
# FlightPath: still to fly= 822.803863464225 nautics
# GreatCircleRoute: initial way-point= turn-pt-3-260.21-degrees - latitude= 48.99 degrees - longitude= 2.46 degrees - altitudeMSL= 1127.86 meters
# BadaAircraft ====================================
# BadaAircraft: entering climb configuration - distance flown 30844.63 meters - distance flown 16.65 nautics
# BadaAircraft: alt= 3038.24 meters alt= 9967.87 feet
# BadaAircraft: tas= 124.77 m/s - tas= 242.54 knots - cas= 107.95 m/s - cas= 209.83 knots - mach= 0.38
# BadaAircraft: real time = 338.00 seconds - 5.00 minutes 38.00 seconds
# BadaAircraft ====================================
# GreatCircleRoute: final way-point= Anticipated-Turn-LAIGLE - latitude= 48.81 degrees - longitude= 0.69 degrees - altitudeMSL= 9090.13 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 1392965.29 meters - still to fly= 752.14 nautics
# FlightPath: passing waypoint: Anticipated-Turn-LAIGLE - alt= 9090.13 meters - alt= 29822.89 feet - distance= 76.77 nautics - real time = 1016.00 seconds - 16.00 minutes 56.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  1 16 climb-ramp-pt-111-9289.12-meters Anticipated-Turn-LAIGLE - latitude= 48.81 degrees - longitude= 0.69 degrees - altitudeMSL= 0.00 meters
# ROLEN - latitude= 48.58 degrees - longitude= 0.16 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 260.32 degrees  to 237.55 degrees - turn step is= -3.00 degrees
# FlightPath: distance to last fix= 737.9958213445515 nautics
# FlightPath: still to fly= 752.1410826752436 nautics
# TurnLeg: tas= 371.07 knots - radius of turn= 13863.23 meters - radius of turn= 7.49 nautics
# TurnLeg: initial heading= 260.32 degrees
# TurnLeg: final heading= 235.78 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 235.78 degrees
# FlightPath: difference= -6.35 degrees
# FlightPath: anticipated turn start from end point= 253925.18 meters
#  ==================== great circle ========================
# FlightPath: distance to last fix= 734.8696817909106 nautics
# FlightPath: still to fly= 748.9580761245165 nautics
# GreatCircleRoute: initial way-point= turn-pt-31-235.78-degrees - latitude= 48.79 degrees - longitude= 0.62 degrees - altitudeMSL= 9258.67 meters
# BadaAircraft: cruise level reached= 10050.12 meters = 32972.42 feet
# BadaAircraft ====================================
# BadaAircraft: entering cruise configuration - distance flown 181245.46 meters - distance flown 97.86 nautics
# BadaAircraft: alt= 10046.06 meters alt= 32959.12 feet
# BadaAircraft: tas= 199.33 m/s - tas= 387.47 knots - cas= 119.92 m/s - cas= 233.11 knots - mach= 0.67
# BadaAircraft: real time = 1217.00 seconds - 20.00 minutes 17.00 seconds
# BadaAircraft ====================================
# GreatCircleRoute: final way-point= ROLEN - latitude= 48.58 degrees - longitude= 0.16 degrees - altitudeMSL= 10050.12 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 1346216.42 meters - still to fly= 726.90 nautics
# FlightPath: passing waypoint: ROLEN - alt= 10050.12 meters - alt= 32972.42 feet - distance= 102.01 nautics - real time = 1254.00 seconds - 20.00 minutes 54.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  2 16 ROLEN ROLEN - latitude= 48.58 degrees - longitude= 0.16 degrees - altitudeMSL= 0.00 meters
# PEPON - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 235.70 degrees  to 229.69 degrees - turn step is= -3.00 degrees
# FlightPath: distance to last fix= 712.849424698285 nautics
# FlightPath: still to fly= 726.898712297572 nautics
# TurnLeg: tas= 403.82 knots - radius of turn= 16418.72 meters - radius of turn= 8.87 nautics
# TurnLeg: initial heading= 235.70 degrees
# TurnLeg: final heading= 229.14 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 229.14 degrees
# FlightPath: difference= -0.57 degrees
# FlightPath: anticipated turn start from end point= 3379486.94 meters
#  ==================== great circle ========================
# FlightPath: distance to last fix= 711.8370835110582 nautics
# FlightPath: still to fly= 725.9240176446212 nautics
# GreatCircleRoute: initial way-point= turn-pt-9-229.14-degrees - latitude= 48.57 degrees - longitude= 0.14 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= PEPON - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 10050.12 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 1306759.90 meters - still to fly= 705.59 nautics
# FlightPath: passing waypoint: PEPON - alt= 10050.12 meters - alt= 32972.42 feet - distance= 123.32 nautics - real time = 1430.00 seconds - 23.00 minutes 50.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  3 16 PEPON PEPON - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 0.00 meters
# KURIS - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 229.27 degrees  to 228.99 degrees - turn step is= -3.00 degrees
# FlightPath: distance to last fix= 691.5462455172833 nautics
# FlightPath: still to fly= 705.5938957997137 nautics
# TurnLeg: tas= 464.98 knots - radius of turn= 21768.28 meters - radius of turn= 11.75 nautics
# TurnLeg: initial heading= 229.27 degrees
# TurnLeg: final heading= 228.64 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 228.36 degrees
# FlightPath: difference= -0.89 degrees
# FlightPath: anticipated turn start from end point= 2810547.50 meters
#  ==================== great circle ========================
# FlightPath: distance to last fix= 691.4170868023776 nautics
# FlightPath: still to fly= 705.5040151214981 nautics
# GreatCircleRoute: initial way-point= turn-pt-1-228.64-degrees - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= KURIS - latitude= 47.59 degrees - longitude= -1.53 degrees - altitudeMSL= 10050.12 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 1179899.20 meters - still to fly= 637.09 nautics
# FlightPath: passing waypoint: KURIS - alt= 10050.12 meters - alt= 32972.42 feet - distance= 191.82 nautics - real time = 1948.00 seconds - 32.00 minutes 28.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  4 16 KURIS KURIS - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 0.00 meters
# TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 228.06 degrees  to 228.10 degrees - turn step is= 3.00 degrees
# FlightPath: distance to last fix= 623.466058531383 nautics
# FlightPath: still to fly= 637.0945978370776 nautics
# TurnLeg: tas= 476.88 knots - radius of turn= 13156.79 meters - radius of turn= 7.10 nautics
# TurnLeg: initial heading= 228.06 degrees
# TurnLeg: final heading= 229.13 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 47.60 degrees
# FlightPath: difference= -16.78 degrees
# FlightPath: anticipated turn start from end point= 155240.95 meters
#  ==================== great circle ========================
# FlightPath: distance to last fix= 623.3336138983527 nautics
# FlightPath: still to fly= 636.7686418405681 nautics
# GreatCircleRoute: initial way-point= turn-pt-1-229.13-degrees - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 10050.12 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 1137589.90 meters - still to fly= 614.25 nautics
# FlightPath: passing waypoint: TERPO - alt= 10050.12 meters - alt= 32972.42 feet - distance= 214.66 nautics - real time = 2119.00 seconds - 35.00 minutes 19.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  5 16 TERPO TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 0.00 meters
# ERIGA - latitude= 46.86 degrees - longitude= -2.36 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 227.81 degrees  to 211.31 degrees - turn step is= -3.00 degrees
# FlightPath: distance to last fix= 600.9567504944379 nautics
# FlightPath: still to fly= 614.249403044182 nautics
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.55 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 227.81 degrees
# TurnLeg: final heading= 210.00 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 210.00 degrees
# FlightPath: difference= 8.06 degrees
# FlightPath: anticipated turn start from end point= 324883.24 meters
#  ==================== great circle ========================
# FlightPath: distance to last fix= 597.16553923819 nautics
# FlightPath: still to fly= 610.530339521329 nautics
# GreatCircleRoute: initial way-point= turn-pt-29-210.00-degrees - latitude= 47.30 degrees - longitude= -1.99 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= ERIGA - latitude= 46.84 degrees - longitude= -2.38 degrees - altitudeMSL= 10050.12 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 1071823.65 meters - still to fly= 578.74 nautics
# FlightPath: passing waypoint: ERIGA - alt= 10050.12 meters - alt= 32972.42 feet - distance= 250.17 nautics - real time = 2388.00 seconds - 39.00 minutes 48.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  6 16 ERIGA ERIGA - latitude= 46.86 degrees - longitude= -2.36 degrees - altitudeMSL= 0.00 meters
# INBAB - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 210.08 degrees  to 218.42 degrees - turn step is= 3.00 degrees
# FlightPath: distance to last fix= 566.6193746084433 nautics
# FlightPath: still to fly= 578.7384729852546 nautics
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.55 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 210.08 degrees
# TurnLeg: final heading= 218.68 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 218.68 degrees
# FlightPath: difference= -1.11 degrees
# FlightPath: anticipated turn start from end point= 2368882.76 meters
#  ==================== great circle ========================
# FlightPath: distance to last fix= 564.770574436188 nautics
# FlightPath: still to fly= 575.9031692249013 nautics
# GreatCircleRoute: initial way-point= turn-pt-14-218.68-degrees - latitude= 46.83 degrees - longitude= -2.39 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= INBAB - latitude= 45.57 degrees - longitude= -3.82 degrees - altitudeMSL= 10050.12 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 887483.79 meters - still to fly= 479.20 nautics
# FlightPath: passing waypoint: INBAB - alt= 10050.12 meters - alt= 32972.42 feet - distance= 349.71 nautics - real time = 3132.00 seconds - 52.00 minutes 12.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  7 16 INBAB INBAB - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 0.00 meters
# ATLEN - latitude= 44.51 degrees - longitude= -4.95 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 217.45 degrees  to 217.36 degrees - turn step is= -3.00 degrees
# FlightPath: distance to last fix= 468.6426643476889 nautics
# FlightPath: still to fly= 479.20290851100805 nautics
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.55 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 217.45 degrees
# TurnLeg: final heading= 216.84 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 37.62 degrees
# FlightPath: difference= 1.44 degrees
# FlightPath: anticipated turn start from end point= 1825221.61 meters
#  ==================== great circle ========================
# FlightPath: distance to last fix= 468.51020379767573 nautics
# FlightPath: still to fly= 478.7630143523466 nautics
# GreatCircleRoute: initial way-point= turn-pt-1-216.84-degrees - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= ATLEN - latitude= 44.50 degrees - longitude= -4.96 degrees - altitudeMSL= 10050.12 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 737019.49 meters - still to fly= 397.96 nautics
# FlightPath: passing waypoint: ATLEN - alt= 10050.12 meters - alt= 32972.42 feet - distance= 430.95 nautics - real time = 3743.00 seconds - 1.00 hours 2.00 minutes 23.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  8 16 ATLEN ATLEN - latitude= 44.51 degrees - longitude= -4.95 degrees - altitudeMSL= 0.00 meters
# DEVAR - latitude= 43.94 degrees - longitude= -5.57 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 216.57 degrees  to 218.80 degrees - turn step is= 3.00 degrees
# FlightPath: distance to last fix= 388.2877460110397 nautics
# FlightPath: still to fly= 397.95868690649047 nautics
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.55 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 216.57 degrees
# TurnLeg: final heading= 219.02 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 219.02 degrees
# FlightPath: difference= 0.40 degrees
# FlightPath: anticipated turn start from end point= 6556282.06 meters
#  ==================== great circle ========================
# FlightPath: distance to last fix= 387.7579594524243 nautics
# FlightPath: still to fly= 397.11187494864174 nautics
# GreatCircleRoute: initial way-point= turn-pt-4-219.02-degrees - latitude= 44.50 degrees - longitude= -4.96 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= DEVAR - latitude= 43.93 degrees - longitude= -5.59 degrees - altitudeMSL= 10050.12 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 654493.20 meters - still to fly= 353.40 nautics
# FlightPath: passing waypoint: DEVAR - alt= 10050.12 meters - alt= 32972.42 feet - distance= 475.51 nautics - real time = 4077.00 seconds - 1.00 hours 7.00 minutes 57.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  9 16 DEVAR DEVAR - latitude= 43.94 degrees - longitude= -5.57 degrees - altitudeMSL= 0.00 meters
# ASTURIAS - latitude= 43.56 degrees - longitude= -6.01 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 218.38 degrees  to 219.20 degrees - turn step is= 3.00 degrees
# FlightPath: distance to last fix= 345.1836240843441 nautics
# FlightPath: still to fly= 353.3980584615397 nautics
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.55 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 218.38 degrees
# TurnLeg: final heading= 219.60 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 219.60 degrees
# FlightPath: difference= -12.28 degrees
# FlightPath: anticipated turn start from end point= 212788.19 meters
#  ==================== great circle ========================
# FlightPath: distance to last fix= 344.9186960349151 nautics
# FlightPath: still to fly= 352.25856868760906 nautics
# GreatCircleRoute: initial way-point= turn-pt-2-219.60-degrees - latitude= 43.94 degrees - longitude= -5.58 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= ASTURIAS - latitude= 43.55 degrees - longitude= -6.02 degrees - altitudeMSL= 10050.12 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 595957.61 meters - still to fly= 321.79 nautics
# FlightPath: passing waypoint: ASTURIAS - alt= 10050.12 meters - alt= 32972.42 feet - distance= 507.12 nautics - real time = 4309.00 seconds - 1.00 hours 11.00 minutes 49.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  10 16 ASTURIAS ASTURIAS - latitude= 43.56 degrees - longitude= -6.01 degrees - altitudeMSL= 0.00 meters
# KUVAN - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 218.91 degrees  to 206.92 degrees - turn step is= -3.00 degrees
# FlightPath: distance to last fix= 315.17321774196745 nautics
# FlightPath: still to fly= 321.7913632572044 nautics
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.55 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 218.91 degrees
# TurnLeg: final heading= 206.02 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 206.02 degrees
# FlightPath: difference= 1.00 degrees
# FlightPath: anticipated turn start from end point= 2636215.67 meters
#  ==================== great circle ========================
# FlightPath: distance to last fix= 312.4100857390364 nautics
# FlightPath: still to fly= 318.5527708876794 nautics
# GreatCircleRoute: initial way-point= turn-pt-21-206.02-degrees - latitude= 43.52 degrees - longitude= -6.04 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= KUVAN - latitude= 43.10 degrees - longitude= -6.32 degrees - altitudeMSL= 10050.12 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 538441.01 meters - still to fly= 290.73 nautics
# FlightPath: passing waypoint: KUVAN - alt= 10050.12 meters - alt= 32972.42 feet - distance= 538.18 nautics - real time = 4540.00 seconds - 1.00 hours 15.00 minutes 40.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  11 16 KUVAN KUVAN - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 0.00 meters
# BISMU - latitude= 42.80 degrees - longitude= -6.54 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 206.18 degrees  to 207.36 degrees - turn step is= 3.00 degrees
# FlightPath: distance to last fix= 285.1326001967474 nautics
# FlightPath: still to fly= 290.73488766861425 nautics
# TurnLeg: tas= 476.88 knots - radius of turn= 13156.79 meters - radius of turn= 7.10 nautics
# TurnLeg: initial heading= 206.18 degrees
# TurnLeg: final heading= 208.31 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 208.31 degrees
# FlightPath: difference= -0.54 degrees
# FlightPath: anticipated turn start from end point= 4882047.89 meters
#  ==================== great circle ========================
# FlightPath: distance to last fix= 284.8676868399269 nautics
# FlightPath: still to fly= 290.1944591859723 nautics
# GreatCircleRoute: initial way-point= turn-pt-2-208.31-degrees - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= BISMU - latitude= 42.79 degrees - longitude= -6.54 degrees - altitudeMSL= 10050.12 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 498187.78 meters - still to fly= 269.00 nautics
# FlightPath: passing waypoint: BISMU - alt= 10050.12 meters - alt= 32972.42 feet - distance= 559.91 nautics - real time = 4702.00 seconds - 1.00 hours 18.00 minutes 22.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  12 16 BISMU BISMU - latitude= 42.80 degrees - longitude= -6.54 degrees - altitudeMSL= 0.00 meters
# BARKO - latitude= 42.20 degrees - longitude= -6.94 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 207.21 degrees  to 206.81 degrees - turn step is= -3.00 degrees
# FlightPath: distance to last fix= 263.8668695352395 nautics
# FlightPath: still to fly= 268.9998814952563 nautics
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.55 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 207.21 degrees
# TurnLeg: final heading= 206.59 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 28.51 degrees
# FlightPath: difference= -1.53 degrees
# FlightPath: anticipated turn start from end point= 1710569.51 meters
#  ==================== great circle ========================
# FlightPath: distance to last fix= 263.73440438257967 nautics
# FlightPath: still to fly= 268.938563809548 nautics
# GreatCircleRoute: initial way-point= turn-pt-1-206.59-degrees - latitude= 42.79 degrees - longitude= -6.54 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= BARKO - latitude= 42.18 degrees - longitude= -6.96 degrees - altitudeMSL= 10050.12 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 422022.78 meters - still to fly= 227.87 nautics
# FlightPath: passing waypoint: BARKO - alt= 10050.12 meters - alt= 32972.42 feet - distance= 601.04 nautics - real time = 5013.00 seconds - 1.00 hours 23.00 minutes 33.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  13 16 BARKO BARKO - latitude= 42.20 degrees - longitude= -6.94 degrees - altitudeMSL= 0.00 meters
# FATIMA - latitude= 39.67 degrees - longitude= -8.49 degrees - altitudeMSL= 0.00 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 206.54 degrees  to 205.28 degrees - turn step is= -3.00 degrees
# FlightPath: distance to last fix= 223.7801022948902 nautics
# FlightPath: still to fly= 227.874069533785 nautics
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.55 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 206.54 degrees
# TurnLeg: final heading= 204.70 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 204.70 degrees
# FlightPath: difference= 4.97 degrees
# FlightPath: anticipated turn start from end point= 527308.03 meters
#  ==================== great circle ========================
# FlightPath: distance to last fix= 223.38271920045716 nautics
# FlightPath: still to fly= 226.63140264263623 nautics
# GreatCircleRoute: initial way-point= turn-pt-3-204.70-degrees - latitude= 42.19 degrees - longitude= -6.95 degrees - altitudeMSL= 10050.12 meters
# BadaAircraft ====================================
# BadaAircraft: entering descent configuration - distance flown 1311721.69 meters - distance flown 708.27 nautics
# BadaAircraft: alt= 10050.12 meters alt= 32972.42 feet
# BadaAircraft: tas= 245.33 m/s - tas= 476.88 knots - cas= 150.36 m/s - cas= 292.28 knots - mach= 0.82
# BadaAircraft: real time = 5856.00 seconds - 1.00 hours 37.00 minutes 36.00 seconds
# BadaAircraft ====================================
# GreatCircleRoute: final way-point= FATIMA - latitude= 39.66 degrees - longitude= -8.49 degrees - altitudeMSL= 5304.57 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 109609.34 meters - still to fly= 59.18 nautics
# FlightPath: passing waypoint: FATIMA - alt= 5304.57 meters - alt= 17403.23 feet - distance= 769.73 nautics - real time = 6391.00 seconds - 1.00 hours 46.00 minutes 31.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  14 16 FATIMA FATIMA - latitude= 39.67 degrees - longitude= -8.49 degrees - altitudeMSL= 0.00 meters
# turn-pt-9-30.44-degrees - latitude= 38.86 degrees - longitude= -9.10 degrees - altitudeMSL= 599.29 meters
# ================== one Turn Leg for each fix in the list ===============
# TurnLeg: turn from= 204.26 degrees  to 210.25 degrees - turn step is= 3.00 degrees
# FlightPath: distance to last fix= 55.985447789398414 nautics
# FlightPath: still to fly= 59.184310088714014 nautics
# TurnLeg: tas= 291.00 knots - radius of turn= 8525.93 meters - radius of turn= 4.60 nautics
# TurnLeg: initial heading= 204.26 degrees
# TurnLeg: final heading= 210.27 degrees
#  ==================== end of turn leg  ====================
# FlightPath: end of turn orientation= 210.27 degrees
#  ==================== great circle ========================
# FlightPath: distance to last fix= 55.503287599536996 nautics
# FlightPath: still to fly= 58.751280685562826 nautics
# GreatCircleRoute: initial way-point= turn-pt-6-210.27-degrees - latitude= 39.66 degrees - longitude= -8.50 degrees - altitudeMSL= 5263.96 meters
# BadaAircraft ====================================
# BadaAircraft: entering approach configuration - distance flown 1502816.76 meters - distance flown 811.46 nautics
# BadaAircraft: alt= 1448.92 meters alt= 4753.62 feet
# BadaAircraft: tas= 58.38 m/s - tas= 113.48 knots - cas= 54.50 m/s - cas= 105.94 knots - mach= 0.17
# BadaAircraft: real time = 7252.00 seconds - 2.00 hours 0.00 minutes 52.00 seconds
# BadaAircraft ====================================
# BadaAircraft: distance to approach fix= 11551.15 meters - delta altitude to approach fix= -520.36 meters
# BadaAircraft ====================================
# BadaAircraft: entering landing configuration - distance flown 1510347.24 meters - distance flown 815.52 nautics
# BadaAircraft: alt= 1109.65 meters alt= 3640.55 feet
# BadaAircraft: tas= 54.17 m/s - tas= 105.30 knots - cas= 51.43 m/s - cas= 99.98 knots - mach= 0.16
# BadaAircraft: real time = 7386.00 seconds - 2.00 hours 3.00 minutes 6.00 seconds
# BadaAircraft ====================================
# GreatCircleRoute: final way-point= turn-pt-9-30.44-degrees - latitude= 38.86 degrees - longitude= -9.10 degrees - altitudeMSL= 565.78 meters
#  ================== end of great circle ==================
# FlightPath: still to fly= 6009.20 meters - still to fly= 3.24 nautics
# FlightPath: passing waypoint: turn-pt-9-30.44-degrees - alt= 565.78 meters - alt= 1856.22 feet - distance= 825.67 nautics - real time = 7607.00 seconds - 2.00 hours 6.00 minutes 47.00 seconds
# 1535145.3027293202
# fix, tailWayPoint:  15 16 turn-pt-9-30.44-degrees turn-pt-9-30.44-degrees - latitude= 38.86 degrees - longitude= -9.10 degrees - altitudeMSL= 599.29 meters
# FlightPath==================== add last turn ====================
# FlightPath: runway final heading= 202.00 degrees
# TurnLeg: turn from= 209.89 degrees  to 202.28 degrees - turn step is= -3.00 degrees
# distanceStillToFlyMeters:  6009.197061707964
# TurnLeg: tas= 108.70 knots - radius of turn= 3643.43 meters - radius of turn= 1.97 nautics
# TurnLeg: initial heading= 209.89 degrees
# TurnLeg: final heading= 201.98 degrees
# FlightPath: distance still to fly= 5.04 nautics
# DescentGlideSlope: airport field Elevation Above Sea Level= 114.00 meters
# DescentGlideSlope: distance from RunWay - TouchDown to RunWay - End= 1440.000000000747 meters
# DescentGlideSlope: bearing from touch-down to runway end= 202.00 degrees
# flowDistanceMeters 1529639.0858582042
# BadaAircraft: distance to runway touch-down= 225.32 meters - delta altitude to runway touch-down= -10.58 meters
# BadaAircraft ====================================
# BadaAircraft: entering arrival-ground-run configuration - distance flown 1531515.06 meters - distance flown 826.95 nautics
# BadaAircraft: alt= 114.57 meters alt= 375.89 feet
# BadaAircraft: tas= 44.85 m/s - tas= 87.19 knots - cas= 44.62 m/s - cas= 86.74 knots - mach= 0.13
# BadaAircraft: real time = 7810.10 seconds - 2.00 hours 10.00 minutes 10.10 seconds
# BadaAircraft ====================================
# GroundRunLeg: ground run - run-way true heading= 22.0 degrees
# BadaAircraft: taxi speed reached => end of simulation
# FlightPath ========== delta mass status ==============
# FlightPath: initial mass= 68000.00 kilograms = 149914.34 pounds
# FlightPath: final mass= 62449.34 kilograms = 137677.22 pounds
# FlightPath: diff mass= 5550.66 kilograms = 12237.12 pounds
# FlightPath ========== delta mass status ==============
# KmlOutput: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/OutputFiles/../ResultsFiles/Paris-Charles-De-Gaulle-Rwy-26R-Lisbon-Lisboa-rwy-03-16-Jan-2020-11h07m55.kml
# FlightPath: final route length= 831.2201103892338 nautics

# %% [markdown]
# ### 2. Generate the list of state vectors of the aircraft at each waypoint in the flight plan
#
# #### Input:
# strRoute: the full flight plan
#
# aircraftICAOcode: type of aircraft
#
# RequestedFlightLevel: Level of cruise phase
#
# WindSpeedMetersPerSecond: wind speed m/s
#
# windDirectionDegrees: direction of wind
#
# #### Output
#
# Generate the list of state vectors of the aircraft at each waypoint in the flight plan and save in ./AircraftTrajectoryPredictionNG/configurations.json

# %%
# If we want to fly through the flight and generate the configuration for later fly, use .fly()

strRoute = 'ADEP/LFPG/26R-LAIGLE-ROLEN-PEPON-KURIS-TERPO-ERIGA-INBAB-ATLEN-DEVAR-ASTURIAS-KUVAN-BISMU-BARKO-FATIMA-ADES/LPPT/03'

flyAndGenerateConfig = FlightPath(route = strRoute,
                                  aircraftICAOcode = 'A320',
                                  RequestedFlightLevel = 330,
                                  cruiseMach = 0.82,
                                  takeOffMassKilograms = 68000.0,
                                  windSpeedMetersPerSecond=25* Knots2MetersPerSecond,
                                  windDirectionDegrees=25)
flyAndGenerateConfig.fly()
# Out:
# FlightPath: route= ADEP/LFPG/26R-LAIGLE-ROLEN-PEPON-KURIS-TERPO-ERIGA-INBAB-ATLEN-DEVAR-ASTURIAS-KUVAN-BISMU-BARKO-FATIMA-ADES/LPPT/03
# WayPointsDatabase: file folder= /home/tanthm/git/ha_bada/AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/Environment
# WayPointsDatabase: file path= /home/tanthm/git/ha_bada/AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/Environment/WayPoints.xls
# AirportsDatabase: file folder= /home/tanthm/git/ha_bada/AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/Environment
# AirportsDatabase: file path= /home/tanthm/git/ha_bada/AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/Environment/Airports.csv
# RunWayDataBase: file folder= /home/tanthm/git/ha_bada/AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/Environment
# RunWayDataBase: file path= /home/tanthm/git/ha_bada/AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/Environment/RunWays.xls
# /home/tanthm/git/ha_bada/AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/Environment/RunWays.xls
# FlightPath: departure airport= Airport: Airport: LFPG - France - Paris-Charles De Gaulle - lat= 49.01 degrees - long= 2.55 degrees - field elevation= 119.48 meters
# FlightPath: departure runway= RunWay: runway= 26R airport ICAO code= LFPG length= 13829.00 feet true heading= 265.00 degrees latitude= 49.00 degrees longitude= 2.61 degrees
# FlightPath: arrival airport= Airport: Airport: LPPT - Portugal - Lisbon-Lisboa - lat= 38.78 degrees - long= -9.14 degrees - field elevation= 114.00 meters
# FlightPath: arrival runway= RunWay: runway= 03 airport ICAO code= LPPT length= 12484.00 feet true heading= 22.00 degrees latitude= 38.77 degrees longitude= -9.14 degrees
# FlightPath: fix= LAIGLE
# FlightPath============ index = 0 ===========
# FlightPath: fix= ROLEN
# Airport: Airport: LFPG - France - Paris-Charles De Gaulle - lat= 49.01 degrees - long= 2.55 degrees - field elevation= 119.48 meters
# LAIGLE - latitude= 48.79 degrees - longitude= 0.53 degrees - altitudeMSL= 0.00 meters
# ROLEN - latitude= 48.58 degrees - longitude= 0.16 degrees - altitudeMSL= 0.00 meters
# FlightPath: Paris-Charles De Gaulle - LAIGLE - ROLEN
# FlightPath: first angle= 261.26 degrees and second angle= 229.66 degrees
# FlightPath: difference= -31.61 degrees
# FlightPath: WARNING - angle difference=  -31.61 greater to 30.00 degrees
# FlightPath============ index = 1 ===========
# FlightPath: fix= PEPON
# LAIGLE - latitude= 48.79 degrees - longitude= 0.53 degrees - altitudeMSL= 0.00 meters
# ROLEN - latitude= 48.58 degrees - longitude= 0.16 degrees - altitudeMSL= 0.00 meters
# PEPON - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 0.00 meters
# FlightPath: LAIGLE - ROLEN - PEPON
# FlightPath: first angle= 229.66 degrees and second angle= 229.69 degrees
# FlightPath: difference= 0.03 degrees
# FlightPath: WARNING - distance between LAIGLE and ROLEN less than 20 Nm = 19.50
# FlightPath============ index = 2 ===========
# FlightPath: fix= KURIS
# ROLEN - latitude= 48.58 degrees - longitude= 0.16 degrees - altitudeMSL= 0.00 meters
# PEPON - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 0.00 meters
# KURIS - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 0.00 meters
# FlightPath: ROLEN - PEPON - KURIS
# FlightPath: first angle= 229.69 degrees and second angle= 228.99 degrees
# FlightPath: difference= -0.70 degrees
# FlightPath============ index = 3 ===========
# FlightPath: fix= TERPO
# PEPON - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 0.00 meters
# KURIS - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 0.00 meters
# TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 0.00 meters
# FlightPath: PEPON - KURIS - TERPO
# FlightPath: first angle= 228.99 degrees and second angle= 228.10 degrees
# FlightPath: difference= -0.89 degrees
# FlightPath============ index = 4 ===========
# FlightPath: fix= ERIGA
# KURIS - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 0.00 meters
# TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 0.00 meters
# ERIGA - latitude= 46.86 degrees - longitude= -2.36 degrees - altitudeMSL= 0.00 meters
# FlightPath: KURIS - TERPO - ERIGA
# FlightPath: first angle= 228.10 degrees and second angle= 211.31 degrees
# FlightPath: difference= -16.79 degrees
# FlightPath============ index = 5 ===========
# FlightPath: fix= INBAB
# TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 0.00 meters
# ERIGA - latitude= 46.86 degrees - longitude= -2.36 degrees - altitudeMSL= 0.00 meters
# INBAB - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 0.00 meters
# FlightPath: TERPO - ERIGA - INBAB
# FlightPath: first angle= 211.31 degrees and second angle= 218.42 degrees
# FlightPath: difference= 7.11 degrees
# FlightPath============ index = 6 ===========
# FlightPath: fix= ATLEN
# ERIGA - latitude= 46.86 degrees - longitude= -2.36 degrees - altitudeMSL= 0.00 meters
# INBAB - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 0.00 meters
# ATLEN - latitude= 44.51 degrees - longitude= -4.95 degrees - altitudeMSL= 0.00 meters
# FlightPath: ERIGA - INBAB - ATLEN
# FlightPath: first angle= 218.42 degrees and second angle= 217.36 degrees
# FlightPath: difference= -1.05 degrees
# FlightPath============ index = 7 ===========
# FlightPath: fix= DEVAR
# INBAB - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 0.00 meters
# ATLEN - latitude= 44.51 degrees - longitude= -4.95 degrees - altitudeMSL= 0.00 meters
# DEVAR - latitude= 43.94 degrees - longitude= -5.57 degrees - altitudeMSL= 0.00 meters
# FlightPath: INBAB - ATLEN - DEVAR
# FlightPath: first angle= 217.36 degrees and second angle= 218.80 degrees
# FlightPath: difference= 1.44 degrees
# FlightPath============ index = 8 ===========
# FlightPath: fix= ASTURIAS
# ATLEN - latitude= 44.51 degrees - longitude= -4.95 degrees - altitudeMSL= 0.00 meters
# DEVAR - latitude= 43.94 degrees - longitude= -5.57 degrees - altitudeMSL= 0.00 meters
# ASTURIAS - latitude= 43.56 degrees - longitude= -6.01 degrees - altitudeMSL= 0.00 meters
# FlightPath: ATLEN - DEVAR - ASTURIAS
# FlightPath: first angle= 218.80 degrees and second angle= 219.20 degrees
# FlightPath: difference= 0.40 degrees
# FlightPath============ index = 9 ===========
# FlightPath: fix= KUVAN
# DEVAR - latitude= 43.94 degrees - longitude= -5.57 degrees - altitudeMSL= 0.00 meters
# ASTURIAS - latitude= 43.56 degrees - longitude= -6.01 degrees - altitudeMSL= 0.00 meters
# KUVAN - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 0.00 meters
# FlightPath: DEVAR - ASTURIAS - KUVAN
# FlightPath: first angle= 219.20 degrees and second angle= 206.92 degrees
# FlightPath: difference= -12.29 degrees
# FlightPath============ index = 10 ===========
# FlightPath: fix= BISMU
# ASTURIAS - latitude= 43.56 degrees - longitude= -6.01 degrees - altitudeMSL= 0.00 meters
# KUVAN - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 0.00 meters
# BISMU - latitude= 42.80 degrees - longitude= -6.54 degrees - altitudeMSL= 0.00 meters
# FlightPath: ASTURIAS - KUVAN - BISMU
# FlightPath: first angle= 206.92 degrees and second angle= 207.36 degrees
# FlightPath: difference= 0.44 degrees
# FlightPath============ index = 11 ===========
# FlightPath: fix= BARKO
# KUVAN - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 0.00 meters
# BISMU - latitude= 42.80 degrees - longitude= -6.54 degrees - altitudeMSL= 0.00 meters
# BARKO - latitude= 42.20 degrees - longitude= -6.94 degrees - altitudeMSL= 0.00 meters
# FlightPath: KUVAN - BISMU - BARKO
# FlightPath: first angle= 207.36 degrees and second angle= 206.81 degrees
# FlightPath: difference= -0.54 degrees
# FlightPath============ index = 12 ===========
# FlightPath: fix= FATIMA
# BISMU - latitude= 42.80 degrees - longitude= -6.54 degrees - altitudeMSL= 0.00 meters
# BARKO - latitude= 42.20 degrees - longitude= -6.94 degrees - altitudeMSL= 0.00 meters
# FATIMA - latitude= 39.67 degrees - longitude= -8.49 degrees - altitudeMSL= 0.00 meters
# FlightPath: BISMU - BARKO - FATIMA
# FlightPath: first angle= 206.81 degrees and second angle= 205.28 degrees
# FlightPath: difference= -1.53 degrees
# FlightPath============ index = 13 ===========
# 1515461.6199379596
# FlightPath: ================ get aircraft =================
# BadaAircraftDatabase: file folder= /home/tanthm/git/ha_bada/AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/BadaAircraftPerformance
# BadaAircraftDatabase: file path= /home/tanthm/git/ha_bada/AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/BadaAircraftPerformance/SYNONYM.NEW
# BadaAircraftDatabase: opening file=  /home/tanthm/git/ha_bada/AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/BadaAircraftPerformance/SYNONYM.NEW
# BadaAircraftDatabase: number of aircrafts in db= 322
# BadaAircraftDatabase: aircraft= A320 exists= True
# BadaAircraftDatabase: aircraft= A320 - found in database
# BadaAircraftDatabase: aircraft= A320 - OPF file= /home/tanthm/git/ha_bada/AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/BadaAircraftPerformance/../Bada381DataFiles/A320__.OPF - exists= True
# FlightPath: performance file= /home/tanthm/git/ha_bada/AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/BadaAircraftPerformance/../Bada381DataFiles/A320__.OPF
# BadaAircraft: Wing Area Surface= 122.6 Square-Meters
# BadaAircraft: stall speed= {'CR': 145.0, 'IC': 120.0, 'TO': 114.0, 'AP': 107.0, 'LD': 101.0} knots
# AircraftMass: aircraft reference mass= 64000.00 kilograms
# AircraftMass: aircraft minimum mass= 39000.00 kilograms
# AircraftMass: aircraft maximum mass= 77000.00 kilograms
# AircraftMass: aircraft maximum pay load mass= 21500.00 kilograms
# BadaAircraft: ===================================================
# BadaAircraft: default configuration= departure-ground-run
# BadaAircraft: ===================================================
# BadaAircraft: transition altitude= 24547.67 feet
# BadaAircraft ICAO code= A320
# BadaAircraft aircraft full name= AIRBUS-A320
# AircraftMass ==========================================================
# AircraftMass: set Aircraft Mass= 68000.00 kilograms - Mass= 149914.34 pounds
# AircraftMass ==========================================================
# BadaAircraft: set Cruise FL= 330 - QNH= 999.25 hecto Pascals - computed Altitude MSL=  10058.40 meters
# 0.82
# BadaAircraft ====================================================
# BadaAircraft: set target cruise Mach= 0.82
# BadaAircraft ====================================================
# BadaAircraftDatabase: aircraft= A320 exists= True
# BadaAircraftDatabase: aircraft= A320 - found in database
# BadaAircraftDatabase: aircraft= A320 - OPF file= /home/tanthm/git/ha_bada/AircraftTrajectoryPredictionNG/AircraftTrajectoryPredictionNG/Home/BadaAircraftPerformance/../Bada381DataFiles/A320__.OPF - exists= True
# BadaAircraft: Wing Area Surface= 122.6 Square-Meters
# BadaAircraft: stall speed= {'CR': 145.0, 'IC': 120.0, 'TO': 114.0, 'AP': 107.0, 'LD': 101.0} knots
# AircraftMass: aircraft reference mass= 64000.00 kilograms
# AircraftMass: aircraft minimum mass= 39000.00 kilograms
# AircraftMass: aircraft maximum mass= 77000.00 kilograms
# AircraftMass: aircraft maximum pay load mass= 21500.00 kilograms
# BadaAircraft: ===================================================
# BadaAircraft: default configuration= departure-ground-run
# BadaAircraft: ===================================================
# BadaAircraft: transition altitude= 24547.67 feet
# AircraftMass ==========================================================
# AircraftMass: set Aircraft Mass= 68000.00 kilograms - Mass= 149914.34 pounds
# AircraftMass ==========================================================
# BadaAircraft: set Cruise FL= 330 - QNH= 999.25 hecto Pascals - computed Altitude MSL=  10058.40 meters
# BadaAircraft ====================================================
# BadaAircraft: set target cruise Mach= 0.82
# BadaAircraft ====================================================
# GroundRunLeg: ground run - run-way true heading= 265.0 degrees
# GroundRunLeg: V stall Calibrated AirSpeed= 117.51 knots
# BadaAircraft: TAS= 143.93 knots - CAS= 143.17 knots > (1.2 * V CAS stall)= 140.94 knots
# BadaAircraft ====================================
# BadaAircraft: entering take-off configuration - distance flown 1667.38 meters - distance flown 0.90 nautics
# BadaAircraft: alt= 119.48 meters alt= 392.00 feet
# BadaAircraft: tas= 72.53 m/s - tas= 141.00 knots - cas= 72.15 m/s - cas= 140.25 knots - mach= 0.21
# BadaAircraft: real time = 45.00 seconds - 0.00 hours 0.00 minutes 45.00 seconds
# BadaAircraft ====================================
# ClimbRamp: run-way orientation degrees= 265.0 degrees
# BadaAircraft: CAS= 145.24 knots >= Initial Climb Stall Speed= 123.62 knots
# BadaAircraft ====================================
# BadaAircraft: entering initial-climb configuration - distance flown 2187.44 meters - distance flown 1.18 nautics
# BadaAircraft: alt= 165.85 meters alt= 544.12 feet
# BadaAircraft: tas= 75.12 m/s - tas= 146.02 knots - cas= 74.57 m/s - cas= 144.95 knots - mach= 0.22
# BadaAircraft: real time = 52.00 seconds - 0.00 hours 0.00 minutes 52.00 seconds
# BadaAircraft ====================================
# GroundRunLeg: ground run - run-way true heading= 22.0 degrees
# ArrivalRunWayTouchDownConstraint: add touch down constraint= Lisbon-Lisboa-Rwy-03-touch-down - latitude= 38.78 degrees - longitude= -9.14 degrees - altitudeMSL= 114.00 meters
# DescentGlideSlope: airport field Elevation Above Sea Level= 114.00 meters
# DescentGlideSlope: distance from RunWay - TouchDown to RunWay - End= 1440.000000000747 meters
# DescentGlideSlope: bearing from touch-down to runway end= 202.00 degrees
# DescentGlideSlope: glide slope Length= 9260.0  meters
# DescentGlideSlope: glide slope orientation= 22.0 degrees
# DescentGlideSlope: distance from last way point to touch-down: 5.00 nautics
# TurnLeg: turn from= 22.00 degrees  to 30.23 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 113.29 knots - radius of turn= 3957.46 meters - radius of turn= 2.14 nautics
# TurnLeg: initial heading= 22.00 degrees
# TargetApproachConstraint: add target approach way point constraint= turn-pt-9-30.44-degrees - latitude= 38.86 degrees - longitude= -9.10 degrees - altitudeMSL= 599.29 meters
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 0
# TurnLeg: turn from= 265.00 degrees  to 261.79 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 183.03 knots - radius of turn= 3372.81 meters - radius of turn= 1.82 nautics
# TurnLeg: initial heading= 265.00 degrees
# TurnLeg: final heading= 260.21 degrees
# GreatCircleRoute: initial way-point= turn-pt-3-260.21-degrees - latitude= 48.99 degrees - longitude= 2.46 degrees - altitudeMSL= 1127.86 meters
# BadaAircraft ====================================
# BadaAircraft: entering climb configuration - distance flown 30844.63 meters - distance flown 16.65 nautics
# BadaAircraft: alt= 3038.24 meters alt= 9967.87 feet
# BadaAircraft: tas= 124.77 m/s - tas= 242.54 knots - cas= 107.95 m/s - cas= 209.83 knots - mach= 0.38
# BadaAircraft: real time = 338.00 seconds - 5.00 minutes 38.00 seconds
# BadaAircraft ====================================
# GreatCircleRoute: final way-point= Anticipated-Turn-LAIGLE - latitude= 48.81 degrees - longitude= 0.69 degrees - altitudeMSL= 9090.13 meters
# Initial heading degrees: 260.3242170745331 <Home.Guidance.GraphFile.Edge object at 0x7f8470e0c080>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 1
# TurnLeg: turn from= 260.32 degrees  to 237.55 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 371.07 knots - radius of turn= 13863.23 meters - radius of turn= 7.49 nautics
# TurnLeg: initial heading= 260.32 degrees
# TurnLeg: final heading= 235.78 degrees
# GreatCircleRoute: initial way-point= turn-pt-31-235.78-degrees - latitude= 48.79 degrees - longitude= 0.62 degrees - altitudeMSL= 9258.67 meters
# BadaAircraft: cruise level reached= 10050.12 meters = 32972.42 feet
# BadaAircraft ====================================
# BadaAircraft: entering cruise configuration - distance flown 181245.46 meters - distance flown 97.86 nautics
# BadaAircraft: alt= 10046.06 meters alt= 32959.12 feet
# BadaAircraft: tas= 199.33 m/s - tas= 387.47 knots - cas= 119.92 m/s - cas= 233.11 knots - mach= 0.67
# BadaAircraft: real time = 1217.00 seconds - 20.00 minutes 17.00 seconds
# BadaAircraft ====================================
# GreatCircleRoute: final way-point= ROLEN - latitude= 48.58 degrees - longitude= 0.16 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 235.69552073910936 <Home.Guidance.GraphFile.Edge object at 0x7f8471e095f8>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 2
# TurnLeg: turn from= 235.70 degrees  to 229.69 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 404.67 knots - radius of turn= 16487.95 meters - radius of turn= 8.90 nautics
# TurnLeg: initial heading= 235.70 degrees
# TurnLeg: final heading= 229.52 degrees
# GreatCircleRoute: initial way-point= turn-pt-9-229.52-degrees - latitude= 48.57 degrees - longitude= 0.14 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= PEPON - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 229.26433207530886 <Home.Guidance.GraphFile.Edge object at 0x7f8471e2c358>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 3
# TurnLeg: turn from= 229.26 degrees  to 228.99 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 467.88 knots - radius of turn= 22040.24 meters - radius of turn= 11.90 nautics
# TurnLeg: initial heading= 229.26 degrees
# TurnLeg: final heading= 228.67 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-228.67-degrees - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= KURIS - latitude= 47.59 degrees - longitude= -1.53 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 228.05299739638141 <Home.Guidance.GraphFile.Edge object at 0x7f8471e0e0f0>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 4
# TurnLeg: turn from= 228.05 degrees  to 228.10 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 13156.80 meters - radius of turn= 7.10 nautics
# TurnLeg: initial heading= 228.05 degrees
# TurnLeg: final heading= 229.07 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-229.07-degrees - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 227.80312239481418 <Home.Guidance.GraphFile.Edge object at 0x7f8471cc9c18>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 5
# TurnLeg: turn from= 227.80 degrees  to 211.31 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 227.80 degrees
# TurnLeg: final heading= 210.26 degrees
# GreatCircleRoute: initial way-point= turn-pt-30-210.26-degrees - latitude= 47.30 degrees - longitude= -1.99 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= ERIGA - latitude= 46.85 degrees - longitude= -2.37 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 210.08051087623033 <Home.Guidance.GraphFile.Edge object at 0x7f8471cda860>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 6
# TurnLeg: turn from= 210.08 degrees  to 218.42 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 210.08 degrees
# TurnLeg: final heading= 218.85 degrees
# GreatCircleRoute: initial way-point= turn-pt-15-218.85-degrees - latitude= 46.83 degrees - longitude= -2.39 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= INBAB - latitude= 45.56 degrees - longitude= -3.83 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 217.44688731354728 <Home.Guidance.GraphFile.Edge object at 0x7f8471e1e518>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 7
# TurnLeg: turn from= 217.45 degrees  to 217.36 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 217.45 degrees
# TurnLeg: final heading= 216.86 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-216.86-degrees - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= ATLEN - latitude= 44.50 degrees - longitude= -4.95 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 216.56626334057745 <Home.Guidance.GraphFile.Edge object at 0x7f8471ccd828>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 8
# TurnLeg: turn from= 216.57 degrees  to 218.80 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 216.57 degrees
# TurnLeg: final heading= 218.91 degrees
# GreatCircleRoute: initial way-point= turn-pt-4-218.91-degrees - latitude= 44.50 degrees - longitude= -4.95 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= DEVAR - latitude= 43.94 degrees - longitude= -5.58 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 218.38357794793163 <Home.Guidance.GraphFile.Edge object at 0x7f8471e0ed68>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 9
# TurnLeg: turn from= 218.38 degrees  to 219.20 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 218.38 degrees
# TurnLeg: final heading= 219.55 degrees
# GreatCircleRoute: initial way-point= turn-pt-2-219.55-degrees - latitude= 43.94 degrees - longitude= -5.58 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= ASTURIAS - latitude= 43.55 degrees - longitude= -6.01 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 218.90938379984297 <Home.Guidance.GraphFile.Edge object at 0x7f8471c31ef0>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 10
# TurnLeg: turn from= 218.91 degrees  to 206.92 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 218.91 degrees
# TurnLeg: final heading= 206.05 degrees
# GreatCircleRoute: initial way-point= turn-pt-22-206.05-degrees - latitude= 43.52 degrees - longitude= -6.04 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= KUVAN - latitude= 43.10 degrees - longitude= -6.32 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 206.17449292519288 <Home.Guidance.GraphFile.Edge object at 0x7f8471dff710>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 11
# TurnLeg: turn from= 206.17 degrees  to 207.36 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 13156.80 meters - radius of turn= 7.10 nautics
# TurnLeg: initial heading= 206.17 degrees
# TurnLeg: final heading= 208.21 degrees
# GreatCircleRoute: initial way-point= turn-pt-2-208.21-degrees - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= BISMU - latitude= 42.79 degrees - longitude= -6.54 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 207.20615441914697 <Home.Guidance.GraphFile.Edge object at 0x7f8471ce5390>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 12
# TurnLeg: turn from= 207.21 degrees  to 206.81 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 207.21 degrees
# TurnLeg: final heading= 206.62 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-206.62-degrees - latitude= 42.79 degrees - longitude= -6.54 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= BARKO - latitude= 42.19 degrees - longitude= -6.95 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 206.54275400780782 <Home.Guidance.GraphFile.Edge object at 0x7f8471c316d8>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 13
# TurnLeg: turn from= 206.54 degrees  to 205.28 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 206.54 degrees
# TurnLeg: final heading= 204.79 degrees
# GreatCircleRoute: initial way-point= turn-pt-3-204.79-degrees - latitude= 42.19 degrees - longitude= -6.95 degrees - altitudeMSL= 10050.12 meters
# BadaAircraft ====================================
# BadaAircraft: entering descent configuration - distance flown 1312211.09 meters - distance flown 708.54 nautics
# BadaAircraft: alt= 10050.12 meters alt= 32972.42 feet
# BadaAircraft: tas= 245.33 m/s - tas= 476.88 knots - cas= 150.36 m/s - cas= 292.28 knots - mach= 0.82
# BadaAircraft: real time = 6089.00 seconds - 1.00 hours 41.00 minutes 29.00 seconds
# BadaAircraft ====================================
# GreatCircleRoute: final way-point= FATIMA - latitude= 39.67 degrees - longitude= -8.49 degrees - altitudeMSL= 5348.17 meters
# Initial heading degrees: 204.26231930869 <Home.Guidance.GraphFile.Edge object at 0x7f8470d288d0>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 14
# TurnLeg: turn from= 204.26 degrees  to 210.25 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 292.73 knots - radius of turn= 8627.75 meters - radius of turn= 4.66 nautics
# TurnLeg: initial heading= 204.26 degrees
# TurnLeg: final heading= 211.23 degrees
# GreatCircleRoute: initial way-point= turn-pt-7-211.23-degrees - latitude= 39.66 degrees - longitude= -8.50 degrees - altitudeMSL= 5300.13 meters
# BadaAircraft ====================================
# BadaAircraft: entering approach configuration - distance flown 1501477.03 meters - distance flown 810.73 nautics
# BadaAircraft: alt= 1449.35 meters alt= 4755.03 feet
# BadaAircraft: tas= 58.31 m/s - tas= 113.35 knots - cas= 54.43 m/s - cas= 105.81 knots - mach= 0.17
# BadaAircraft: real time = 7473.00 seconds - 2.00 hours 4.00 minutes 33.00 seconds
# BadaAircraft ====================================
# BadaAircraft: distance to approach fix= 11451.48 meters - delta altitude to approach fix= -520.64 meters
# BadaAircraft ====================================
# BadaAircraft: entering landing configuration - distance flown 1508941.79 meters - distance flown 814.76 nautics
# BadaAircraft: alt= 1109.93 meters alt= 3641.47 feet
# BadaAircraft: tas= 54.10 m/s - tas= 105.16 knots - cas= 51.36 m/s - cas= 99.84 knots - mach= 0.16
# BadaAircraft: real time = 7606.00 seconds - 2.00 hours 6.00 minutes 46.00 seconds
# BadaAircraft ====================================
# GreatCircleRoute: final way-point= turn-pt-9-30.44-degrees - latitude= 38.86 degrees - longitude= -9.10 degrees - altitudeMSL= 566.59 meters
# Initial heading degrees: 209.88597209142776 <Home.Guidance.GraphFile.Edge object at 0x7f8470bc9470>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'FATIMA', 'turn-pt-9-30.44-degrees'] 15

# %% [markdown]
# ### 3. Generate the trajectory of aircraft from a waypoint to destination airport
#
# Ensure that you generate the state vectors of aircraft at all waypoints (part 2)
#
# #### Input:
# strRoute: the full flight plan
#
# aircraftICAOcode: type of aircraft
#
# RequestedFlightLevel: Level of cruise phase
#
# WindSpeedMetersPerSecond: wind speed m/s
#
# windDirectionDegrees: direction of wind
#
# Index of the waypoint
#
# Current speed
#
# Current altitude
#
# #### Output
#
# Generate the trajectory of aircraft from a waypoint to destination airport and save in ./ResultsFiles

# %%
# If we want to simulate the fly based on previous configuration, use .simulateFly
strRoute = 'ADEP/LFPG/26R-LAIGLE-ROLEN-PEPON-KURIS-TERPO-ERIGA-INBAB-ATLEN-DEVAR-ASTURIAS-KUVAN-BISMU-BARKO-ADES/LPPT/03'

updateFlightPath = FlightPath(route = strRoute,
                             aircraftICAOcode = 'A320',
                             RequestedFlightLevel = 330,
                             cruiseMach = 0.82,
                             takeOffMassKilograms = 68000.0,
                             windSpeedMetersPerSecond=25* Knots2MetersPerSecond,
                             windDirectionDegrees=25)

# fly from index 4 for the new route
updateFlightPath.simulateFly(4, strRoute)
# fly from index 4 for the new route, with speed 260 and altitude 10000
updateFlightPath.simulateFly(4, strRoute, 260, 10000.0)
# Out:
# FlightPath: route= ADEP/LFPG/26R-LAIGLE-ROLEN-PEPON-KURIS-TERPO-ERIGA-INBAB-ATLEN-DEVAR-ASTURIAS-KUVAN-BISMU-BARKO-ADES/LPPT/03
# WayPointsDatabase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# WayPointsDatabase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/WayPoints.xls
# AirportsDatabase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# AirportsDatabase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/Airports.csv
# RunWayDataBase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# RunWayDataBase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/RunWays.xls
# /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/RunWays.xls
# FlightPath: departure airport= Airport: Airport: LFPG - France - Paris-Charles De Gaulle - lat= 49.01 degrees - long= 2.55 degrees - field elevation= 119.48 meters
# FlightPath: departure runway= RunWay: runway= 26R airport ICAO code= LFPG length= 13829.00 feet true heading= 265.00 degrees latitude= 49.00 degrees longitude= 2.61 degrees
# FlightPath: arrival airport= Airport: Airport: LPPT - Portugal - Lisbon-Lisboa - lat= 38.78 degrees - long= -9.14 degrees - field elevation= 114.00 meters
# FlightPath: arrival runway= RunWay: runway= 03 airport ICAO code= LPPT length= 12484.00 feet true heading= 22.00 degrees latitude= 38.77 degrees longitude= -9.14 degrees
# FlightPath: fix= LAIGLE
# FlightPath============ index = 0 ===========
# FlightPath: fix= ROLEN
# Airport: Airport: LFPG - France - Paris-Charles De Gaulle - lat= 49.01 degrees - long= 2.55 degrees - field elevation= 119.48 meters
# LAIGLE - latitude= 48.79 degrees - longitude= 0.53 degrees - altitudeMSL= 0.00 meters
# ROLEN - latitude= 48.58 degrees - longitude= 0.16 degrees - altitudeMSL= 0.00 meters
# FlightPath: Paris-Charles De Gaulle - LAIGLE - ROLEN
# FlightPath: first angle= 261.26 degrees and second angle= 229.66 degrees
# FlightPath: difference= -31.61 degrees
# FlightPath: WARNING - angle difference=  -31.61 greater to 30.00 degrees
# FlightPath============ index = 1 ===========
# FlightPath: fix= PEPON
# LAIGLE - latitude= 48.79 degrees - longitude= 0.53 degrees - altitudeMSL= 0.00 meters
# ROLEN - latitude= 48.58 degrees - longitude= 0.16 degrees - altitudeMSL= 0.00 meters
# PEPON - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 0.00 meters
# FlightPath: LAIGLE - ROLEN - PEPON
# FlightPath: first angle= 229.66 degrees and second angle= 229.69 degrees
# FlightPath: difference= 0.03 degrees
# FlightPath: WARNING - distance between LAIGLE and ROLEN less than 20 Nm = 19.50
# FlightPath============ index = 2 ===========
# FlightPath: fix= KURIS
# ROLEN - latitude= 48.58 degrees - longitude= 0.16 degrees - altitudeMSL= 0.00 meters
# PEPON - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 0.00 meters
# KURIS - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 0.00 meters
# FlightPath: ROLEN - PEPON - KURIS
# FlightPath: first angle= 229.69 degrees and second angle= 228.99 degrees
# FlightPath: difference= -0.70 degrees
# FlightPath============ index = 3 ===========
# FlightPath: fix= TERPO
# PEPON - latitude= 48.35 degrees - longitude= -0.25 degrees - altitudeMSL= 0.00 meters
# KURIS - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 0.00 meters
# TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 0.00 meters
# FlightPath: PEPON - KURIS - TERPO
# FlightPath: first angle= 228.99 degrees and second angle= 228.10 degrees
# FlightPath: difference= -0.89 degrees
# FlightPath============ index = 4 ===========
# FlightPath: fix= ERIGA
# KURIS - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 0.00 meters
# TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 0.00 meters
# ERIGA - latitude= 46.86 degrees - longitude= -2.36 degrees - altitudeMSL= 0.00 meters
# FlightPath: KURIS - TERPO - ERIGA
# FlightPath: first angle= 228.10 degrees and second angle= 211.31 degrees
# FlightPath: difference= -16.79 degrees
# FlightPath============ index = 5 ===========
# FlightPath: fix= INBAB
# TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 0.00 meters
# ERIGA - latitude= 46.86 degrees - longitude= -2.36 degrees - altitudeMSL= 0.00 meters
# INBAB - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 0.00 meters
# FlightPath: TERPO - ERIGA - INBAB
# FlightPath: first angle= 211.31 degrees and second angle= 218.42 degrees
# FlightPath: difference= 7.11 degrees
# FlightPath============ index = 6 ===========
# FlightPath: fix= ATLEN
# ERIGA - latitude= 46.86 degrees - longitude= -2.36 degrees - altitudeMSL= 0.00 meters
# INBAB - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 0.00 meters
# ATLEN - latitude= 44.51 degrees - longitude= -4.95 degrees - altitudeMSL= 0.00 meters
# FlightPath: ERIGA - INBAB - ATLEN
# FlightPath: first angle= 218.42 degrees and second angle= 217.36 degrees
# FlightPath: difference= -1.05 degrees
# FlightPath============ index = 7 ===========
# FlightPath: fix= DEVAR
# INBAB - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 0.00 meters
# ATLEN - latitude= 44.51 degrees - longitude= -4.95 degrees - altitudeMSL= 0.00 meters
# DEVAR - latitude= 43.94 degrees - longitude= -5.57 degrees - altitudeMSL= 0.00 meters
# FlightPath: INBAB - ATLEN - DEVAR
# FlightPath: first angle= 217.36 degrees and second angle= 218.80 degrees
# FlightPath: difference= 1.44 degrees
# FlightPath============ index = 8 ===========
# FlightPath: fix= ASTURIAS
# ATLEN - latitude= 44.51 degrees - longitude= -4.95 degrees - altitudeMSL= 0.00 meters
# DEVAR - latitude= 43.94 degrees - longitude= -5.57 degrees - altitudeMSL= 0.00 meters
# ASTURIAS - latitude= 43.56 degrees - longitude= -6.01 degrees - altitudeMSL= 0.00 meters
# FlightPath: ATLEN - DEVAR - ASTURIAS
# FlightPath: first angle= 218.80 degrees and second angle= 219.20 degrees
# FlightPath: difference= 0.40 degrees
# FlightPath============ index = 9 ===========
# FlightPath: fix= KUVAN
# DEVAR - latitude= 43.94 degrees - longitude= -5.57 degrees - altitudeMSL= 0.00 meters
# ASTURIAS - latitude= 43.56 degrees - longitude= -6.01 degrees - altitudeMSL= 0.00 meters
# KUVAN - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 0.00 meters
# FlightPath: DEVAR - ASTURIAS - KUVAN
# FlightPath: first angle= 219.20 degrees and second angle= 206.92 degrees
# FlightPath: difference= -12.29 degrees
# FlightPath============ index = 10 ===========
# FlightPath: fix= BISMU
# ASTURIAS - latitude= 43.56 degrees - longitude= -6.01 degrees - altitudeMSL= 0.00 meters
# KUVAN - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 0.00 meters
# BISMU - latitude= 42.80 degrees - longitude= -6.54 degrees - altitudeMSL= 0.00 meters
# FlightPath: ASTURIAS - KUVAN - BISMU
# FlightPath: first angle= 206.92 degrees and second angle= 207.36 degrees
# FlightPath: difference= 0.44 degrees
# FlightPath============ index = 11 ===========
# FlightPath: fix= BARKO
# KUVAN - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 0.00 meters
# BISMU - latitude= 42.80 degrees - longitude= -6.54 degrees - altitudeMSL= 0.00 meters
# BARKO - latitude= 42.20 degrees - longitude= -6.94 degrees - altitudeMSL= 0.00 meters
# FlightPath: KUVAN - BISMU - BARKO
# FlightPath: first angle= 207.36 degrees and second angle= 206.81 degrees
# FlightPath: difference= -0.54 degrees
# FlightPath============ index = 12 ===========
# 1515101.3925807453
# FlightPath: ================ get aircraft =================
# BadaAircraftDatabase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance
# BadaAircraftDatabase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/SYNONYM.NEW
# BadaAircraftDatabase: opening file=  /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/SYNONYM.NEW
# BadaAircraftDatabase: number of aircrafts in db= 322
# BadaAircraftDatabase: aircraft= A320 exists= True
# BadaAircraftDatabase: aircraft= A320 - found in database
# BadaAircraftDatabase: aircraft= A320 - OPF file= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/../Bada381DataFiles/A320__.OPF - exists= True
# FlightPath: performance file= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/../Bada381DataFiles/A320__.OPF
# BadaAircraft: Wing Area Surface= 122.6 Square-Meters
# BadaAircraft: stall speed= {'CR': 145.0, 'IC': 120.0, 'TO': 114.0, 'AP': 107.0, 'LD': 101.0} knots
# AircraftMass: aircraft reference mass= 64000.00 kilograms
# AircraftMass: aircraft minimum mass= 39000.00 kilograms
# AircraftMass: aircraft maximum mass= 77000.00 kilograms
# AircraftMass: aircraft maximum pay load mass= 21500.00 kilograms
# BadaAircraft: ===================================================
# BadaAircraft: default configuration= departure-ground-run
# BadaAircraft: ===================================================
# BadaAircraft: transition altitude= 24547.67 feet
# BadaAircraft ICAO code= A320
# BadaAircraft aircraft full name= AIRBUS-A320
# AircraftMass ==========================================================
# AircraftMass: set Aircraft Mass= 68000.00 kilograms - Mass= 149914.34 pounds
# AircraftMass ==========================================================
# BadaAircraft: set Cruise FL= 330 - QNH= 999.25 hecto Pascals - computed Altitude MSL=  10058.40 meters
# 0.82
# BadaAircraft====================================================
# BadaAircraft: set target cruise Mach= 0.82
# BadaAircraft====================================================
# WayPointsDatabase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# WayPointsDatabase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/WayPoints.xls
# AirportsDatabase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# AirportsDatabase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/Airports.csv
# RunWayDataBase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# RunWayDataBase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/RunWays.xls
# /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/RunWays.xls
# BadaAircraftDatabase: aircraft= A320 exists= True
# BadaAircraftDatabase: aircraft= A320 - found in database
# BadaAircraftDatabase: aircraft= A320 - OPF file= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/../Bada381DataFiles/A320__.OPF - exists= True
# BadaAircraft: Wing Area Surface= 122.6 Square-Meters
# BadaAircraft: stall speed= {'CR': 145.0, 'IC': 120.0, 'TO': 114.0, 'AP': 107.0, 'LD': 101.0} knots
# AircraftMass: aircraft reference mass= 64000.00 kilograms
# AircraftMass: aircraft minimum mass= 39000.00 kilograms
# AircraftMass: aircraft maximum mass= 77000.00 kilograms
# AircraftMass: aircraft maximum pay load mass= 21500.00 kilograms
# BadaAircraft: ===================================================
# BadaAircraft: default configuration= departure-ground-run
# BadaAircraft: ===================================================
# BadaAircraft: transition altitude= 24547.67 feet
# AircraftMass ==========================================================
# AircraftMass: set Aircraft Mass= 68000.00 kilograms - Mass= 149914.34 pounds
# AircraftMass ==========================================================
# BadaAircraft: set Cruise FL= 330 - QNH= 999.25 hecto Pascals - computed Altitude MSL=  10058.40 meters
# BadaAircraft====================================================
# BadaAircraft: set target cruise Mach= 0.82
# BadaAircraft====================================================
# GroundRunLeg: ground run - run-way true heading= 265.0 degrees
# GroundRunLeg: V stall Calibrated AirSpeed= 117.51 knots
# BadaAircraft: TAS= 143.93 knots - CAS= 143.17 knots > (1.2 * V CAS stall)= 140.94 knots
# BadaAircraft ====================================
# BadaAircraft: entering take-off configuration - distance flown 1667.38 meters - distance flown 0.90 nautics
# BadaAircraft: alt= 119.48 meters alt= 392.00 feet
# BadaAircraft: tas= 72.53 m/s - tas= 141.00 knots - cas= 72.15 m/s - cas= 140.25 knots - mach= 0.21
# BadaAircraft: real time = 45.00 seconds - 0.00 hours 0.00 minutes 45.00 seconds
# BadaAircraft ====================================
# ClimbRamp: run-way orientation degrees= 265.0 degrees
# BadaAircraft: CAS= 145.24 knots >= Initial Climb Stall Speed= 123.62 knots
# BadaAircraft ====================================
# BadaAircraft: entering initial-climb configuration - distance flown 2187.44 meters - distance flown 1.18 nautics
# BadaAircraft: alt= 165.85 meters alt= 544.12 feet
# BadaAircraft: tas= 75.12 m/s - tas= 146.02 knots - cas= 74.57 m/s - cas= 144.95 knots - mach= 0.22
# BadaAircraft: real time = 52.00 seconds - 0.00 hours 0.00 minutes 52.00 seconds
# BadaAircraft ====================================
# GroundRunLeg: ground run - run-way true heading= 22.0 degrees
# ArrivalRunWayTouchDownConstraint: add touch down constraint= Lisbon-Lisboa-Rwy-03-touch-down - latitude= 38.78 degrees - longitude= -9.14 degrees - altitudeMSL= 114.00 meters
# DescentGlideSlope: airport field Elevation Above Sea Level= 114.00 meters
# DescentGlideSlope: distance from RunWay - TouchDown to RunWay - End= 1440.000000000747 meters
# DescentGlideSlope: bearing from touch-down to runway end= 202.00 degrees
# DescentGlideSlope: glide slope Length= 9260.0  meters
# DescentGlideSlope: glide slope orientation= 22.0 degrees
# DescentGlideSlope: distance from last way point to touch-down: 5.00 nautics
# TurnLeg: turn from= 22.00 degrees  to 26.78 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 113.29 knots - radius of turn= 3957.46 meters - radius of turn= 2.14 nautics
# TurnLeg: initial heading= 22.00 degrees
# TargetApproachConstraint: add target approach way point constraint= turn-pt-4-26.22-degrees - latitude= 38.86 degrees - longitude= -9.10 degrees - altitudeMSL= 599.29 meters
# BadaAircraftDatabase: aircraft= A320 exists= True
# BadaAircraftDatabase: aircraft= A320 - found in database
# BadaAircraftDatabase: aircraft= A320 - OPF file= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/../Bada381DataFiles/A320__.OPF - exists= True
# BadaAircraft: Wing Area Surface= 122.6 Square-Meters
# BadaAircraft: stall speed= {'CR': 145.0, 'IC': 120.0, 'TO': 114.0, 'AP': 107.0, 'LD': 101.0} knots
# AircraftMass: aircraft reference mass= 64000.00 kilograms
# AircraftMass: aircraft minimum mass= 39000.00 kilograms
# AircraftMass: aircraft maximum mass= 77000.00 kilograms
# AircraftMass: aircraft maximum pay load mass= 21500.00 kilograms
# BadaAircraft: ===================================================
# BadaAircraft: default configuration= departure-ground-run
# BadaAircraft: ===================================================
# BadaAircraft: transition altitude= 24547.67 feet
# AircraftMass ==========================================================
# AircraftMass: set Aircraft Mass= 68000.00 kilograms - Mass= 149914.34 pounds
# AircraftMass ==========================================================
# BadaAircraft: set Cruise FL= 330 - QNH= 999.25 hecto Pascals - computed Altitude MSL=  10058.40 meters
# BadaAircraft====================================================
# BadaAircraft: set target cruise Mach= 0.82
# BadaAircraft====================================================
# AircraftMass ==========================================================
# AircraftMass: set Aircraft Mass= 65803.97 kilograms - Mass= 145072.92 pounds
# AircraftMass ==========================================================
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-4-26.22-degrees'] 4
# TurnLeg: turn from= 228.05 degrees  to 228.10 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 13156.80 meters - radius of turn= 7.10 nautics
# TurnLeg: initial heading= 228.05 degrees
# TurnLeg: final heading= 229.07 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-229.07-degrees - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 227.80312239481418 <Home.Guidance.GraphFile.Edge object at 0x7f49e4ba3518>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-4-26.22-degrees'] 5
# TurnLeg: turn from= 227.80 degrees  to 211.31 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 227.80 degrees
# TurnLeg: final heading= 210.26 degrees
# GreatCircleRoute: initial way-point= turn-pt-30-210.26-degrees - latitude= 47.30 degrees - longitude= -1.99 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= ERIGA - latitude= 46.85 degrees - longitude= -2.37 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 210.08051087623033 <Home.Guidance.GraphFile.Edge object at 0x7f49e4bbf358>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-4-26.22-degrees'] 6
# TurnLeg: turn from= 210.08 degrees  to 218.42 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 210.08 degrees
# TurnLeg: final heading= 218.85 degrees
# GreatCircleRoute: initial way-point= turn-pt-15-218.85-degrees - latitude= 46.83 degrees - longitude= -2.39 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= INBAB - latitude= 45.56 degrees - longitude= -3.83 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 217.44688731354728 <Home.Guidance.GraphFile.Edge object at 0x7f49e4b8dc18>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-4-26.22-degrees'] 7
# TurnLeg: turn from= 217.45 degrees  to 217.36 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 217.45 degrees
# TurnLeg: final heading= 216.86 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-216.86-degrees - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= ATLEN - latitude= 44.50 degrees - longitude= -4.95 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 216.56626334057745 <Home.Guidance.GraphFile.Edge object at 0x7f49e4b6deb8>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-4-26.22-degrees'] 8
# TurnLeg: turn from= 216.57 degrees  to 218.80 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 216.57 degrees
# TurnLeg: final heading= 218.91 degrees
# GreatCircleRoute: initial way-point= turn-pt-4-218.91-degrees - latitude= 44.50 degrees - longitude= -4.95 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= DEVAR - latitude= 43.94 degrees - longitude= -5.58 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 218.38357794793163 <Home.Guidance.GraphFile.Edge object at 0x7f49e4b5e128>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-4-26.22-degrees'] 9
# TurnLeg: turn from= 218.38 degrees  to 219.20 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 218.38 degrees
# TurnLeg: final heading= 219.55 degrees
# GreatCircleRoute: initial way-point= turn-pt-2-219.55-degrees - latitude= 43.94 degrees - longitude= -5.58 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= ASTURIAS - latitude= 43.55 degrees - longitude= -6.01 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 218.90938379984297 <Home.Guidance.GraphFile.Edge object at 0x7f49e4b66eb8>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-4-26.22-degrees'] 10
# TurnLeg: turn from= 218.91 degrees  to 206.92 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 218.91 degrees
# TurnLeg: final heading= 206.05 degrees
# GreatCircleRoute: initial way-point= turn-pt-22-206.05-degrees - latitude= 43.52 degrees - longitude= -6.04 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= KUVAN - latitude= 43.10 degrees - longitude= -6.32 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 206.17449292519288 <Home.Guidance.GraphFile.Edge object at 0x7f49e4a9d390>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-4-26.22-degrees'] 11
# TurnLeg: turn from= 206.17 degrees  to 207.36 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 13156.80 meters - radius of turn= 7.10 nautics
# TurnLeg: initial heading= 206.17 degrees
# TurnLeg: final heading= 208.21 degrees
# GreatCircleRoute: initial way-point= turn-pt-2-208.21-degrees - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= BISMU - latitude= 42.79 degrees - longitude= -6.54 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 207.20615441914697 <Home.Guidance.GraphFile.Edge object at 0x7f49e4aa37f0>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-4-26.22-degrees'] 12
# TurnLeg: turn from= 207.21 degrees  to 206.81 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 207.21 degrees
# TurnLeg: final heading= 206.62 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-206.62-degrees - latitude= 42.79 degrees - longitude= -6.54 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= BARKO - latitude= 42.19 degrees - longitude= -6.95 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 206.54275400780782 <Home.Guidance.GraphFile.Edge object at 0x7f49e4aaf160>
# ['climb-ramp-pt-111-9289.12-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-4-26.22-degrees'] 13
# TurnLeg: turn from= 206.54 degrees  to 206.78 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 206.54 degrees
# TurnLeg: final heading= 207.13 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-207.13-degrees - latitude= 42.20 degrees - longitude= -6.95 degrees - altitudeMSL= 10050.12 meters
# BadaAircraft ====================================
# BadaAircraft: entering descent configuration - distance flown 1311743.75 meters - distance flown 708.28 nautics
# BadaAircraft: alt= 10050.12 meters alt= 32972.42 feet
# BadaAircraft: tas= 245.33 m/s - tas= 476.88 knots - cas= 150.36 m/s - cas= 292.28 knots - mach= 0.82
# BadaAircraft: real time = 6087.00 seconds - 1.00 hours 41.00 minutes 27.00 seconds
# BadaAircraft ====================================
# BadaAircraft ====================================
# BadaAircraft: entering approach configuration - distance flown 1501273.90 meters - distance flown 810.62 nautics
# BadaAircraft: alt= 1448.37 meters alt= 4751.81 feet
# BadaAircraft: tas= 58.29 m/s - tas= 113.30 knots - cas= 54.41 m/s - cas= 105.77 knots - mach= 0.17
# BadaAircraft: real time = 7473.00 seconds - 2.00 hours 4.00 minutes 33.00 seconds
# BadaAircraft ====================================
# BadaAircraft: distance to approach fix= 11451.03 meters - delta altitude to approach fix= -520.11 meters
# BadaAircraft ====================================
# BadaAircraft: entering landing configuration - distance flown 1508735.98 meters - distance flown 814.65 nautics
# BadaAircraft: alt= 1109.41 meters alt= 3639.74 feet
# BadaAircraft: tas= 54.08 m/s - tas= 105.13 knots - cas= 51.35 m/s - cas= 99.81 knots - mach= 0.16
# BadaAircraft: real time = 7606.00 seconds - 2.00 hours 6.00 minutes 46.00 seconds
# BadaAircraft ====================================
# GreatCircleRoute: final way-point= turn-pt-4-26.22-degrees - latitude= 38.86 degrees - longitude= -9.10 degrees - altitudeMSL= 559.76 meters
# Initial heading degrees: 205.37699622723252 <Home.Guidance.GraphFile.Edge object at 0x7f49e3a805c0>
# turn-pt-4-26.22-degrees - latitude= 38.86 degrees - longitude= -9.10 degrees - altitudeMSL= 559.76 meters
# TurnLeg: turn from= 205.38 degrees  to 202.08 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 108.51 knots - radius of turn= 3630.99 meters - radius of turn= 1.96 nautics
# TurnLeg: initial heading= 205.38 degrees
# TurnLeg: final heading= 201.92 degrees
# DescentGlideSlope: airport field Elevation Above Sea Level= 114.00 meters
# DescentGlideSlope: distance from RunWay - TouchDown to RunWay - End= 1440.000000000747 meters
# DescentGlideSlope: bearing from touch-down to runway end= 202.00 degrees
# BadaAircraft: distance to runway touch-down= 250.05 meters - delta altitude to runway touch-down= -11.97 meters
# BadaAircraft ====================================
# BadaAircraft: entering arrival-ground-run configuration - distance flown 1529488.19 meters - distance flown 825.86 nautics
# BadaAircraft: alt= 115.96 meters alt= 380.45 feet
# BadaAircraft: tas= 44.80 m/s - tas= 87.09 knots - cas= 44.57 m/s - cas= 86.64 knots - mach= 0.13
# BadaAircraft: real time = 8022.40 seconds - 2.00 hours 13.00 minutes 42.40 seconds
# BadaAircraft ====================================
# GroundRunLeg: ground run - run-way true heading= 22.0 degrees
# BadaAircraft: taxi speed reached => end of simulation
# WayPointsDatabase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# WayPointsDatabase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/WayPoints.xls
# AirportsDatabase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# AirportsDatabase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/Airports.csv
# RunWayDataBase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# RunWayDataBase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/RunWays.xls
# /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/RunWays.xls
# BadaAircraftDatabase: aircraft= A320 exists= True
# BadaAircraftDatabase: aircraft= A320 - found in database
# BadaAircraftDatabase: aircraft= A320 - OPF file= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/../Bada381DataFiles/A320__.OPF - exists= True
# BadaAircraft: Wing Area Surface= 122.6 Square-Meters
# BadaAircraft: stall speed= {'CR': 145.0, 'IC': 120.0, 'TO': 114.0, 'AP': 107.0, 'LD': 101.0} knots
# AircraftMass: aircraft reference mass= 64000.00 kilograms
# AircraftMass: aircraft minimum mass= 39000.00 kilograms
# AircraftMass: aircraft maximum mass= 77000.00 kilograms
# AircraftMass: aircraft maximum pay load mass= 21500.00 kilograms
# BadaAircraft: ===================================================
# BadaAircraft: default configuration= departure-ground-run
# BadaAircraft: ===================================================
# BadaAircraft: transition altitude= 24547.67 feet
# AircraftMass ==========================================================
# AircraftMass: set Aircraft Mass= 68000.00 kilograms - Mass= 149914.34 pounds
# AircraftMass ==========================================================
# BadaAircraft: set Cruise FL= 330 - QNH= 999.25 hecto Pascals - computed Altitude MSL=  10058.40 meters
# BadaAircraft====================================================
# BadaAircraft: set target cruise Mach= 0.82
# BadaAircraft====================================================
# GroundRunLeg: ground run - run-way true heading= 265.0 degrees
# GroundRunLeg: V stall Calibrated AirSpeed= 117.51 knots
# BadaAircraft: TAS= 143.93 knots - CAS= 143.17 knots > (1.2 * V CAS stall)= 140.94 knots
# BadaAircraft ====================================
# BadaAircraft: entering take-off configuration - distance flown 1667.38 meters - distance flown 0.90 nautics
# BadaAircraft: alt= 119.48 meters alt= 392.00 feet
# BadaAircraft: tas= 72.53 m/s - tas= 141.00 knots - cas= 72.15 m/s - cas= 140.25 knots - mach= 0.21
# BadaAircraft: real time = 45.00 seconds - 0.00 hours 0.00 minutes 45.00 seconds
# BadaAircraft ====================================
# ClimbRamp: run-way orientation degrees= 265.0 degrees
# BadaAircraft: CAS= 145.24 knots >= Initial Climb Stall Speed= 123.62 knots
# BadaAircraft ====================================
# BadaAircraft: entering initial-climb configuration - distance flown 2187.44 meters - distance flown 1.18 nautics
# BadaAircraft: alt= 165.85 meters alt= 544.12 feet
# BadaAircraft: tas= 75.12 m/s - tas= 146.02 knots - cas= 74.57 m/s - cas= 144.95 knots - mach= 0.22
# BadaAircraft: real time = 52.00 seconds - 0.00 hours 0.00 minutes 52.00 seconds
# BadaAircraft ====================================
# GroundRunLeg: ground run - run-way true heading= 22.0 degrees
# ArrivalRunWayTouchDownConstraint: add touch down constraint= Lisbon-Lisboa-Rwy-03-touch-down - latitude= 38.78 degrees - longitude= -9.14 degrees - altitudeMSL= 114.00 meters
# DescentGlideSlope: airport field Elevation Above Sea Level= 114.00 meters
# DescentGlideSlope: distance from RunWay - TouchDown to RunWay - End= 1440.000000000747 meters
# DescentGlideSlope: bearing from touch-down to runway end= 202.00 degrees
# DescentGlideSlope: glide slope Length= 4775.531703014067  meters
# DescentGlideSlope: glide slope orientation= 22.0 degrees
# DescentGlideSlope: distance from last way point to touch-down: 2.58 nautics
# TurnLeg: turn from= 22.00 degrees  to 22.16 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 112.09 knots - radius of turn= 3874.02 meters - radius of turn= 2.09 nautics
# TurnLeg: initial heading= 22.00 degrees
# TargetApproachConstraint: add target approach way point constraint= turn-pt-0-22.85-degrees - latitude= 38.82 degrees - longitude= -9.12 degrees - altitudeMSL= 364.27 meters
# BadaAircraftDatabase: aircraft= A320 exists= True
# BadaAircraftDatabase: aircraft= A320 - found in database
# BadaAircraftDatabase: aircraft= A320 - OPF file= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/../Bada381DataFiles/A320__.OPF - exists= True
# BadaAircraft: Wing Area Surface= 122.6 Square-Meters
# BadaAircraft: stall speed= {'CR': 145.0, 'IC': 120.0, 'TO': 114.0, 'AP': 107.0, 'LD': 101.0} knots
# AircraftMass: aircraft reference mass= 64000.00 kilograms
# AircraftMass: aircraft minimum mass= 39000.00 kilograms
# AircraftMass: aircraft maximum mass= 77000.00 kilograms
# AircraftMass: aircraft maximum pay load mass= 21500.00 kilograms
# BadaAircraft: ===================================================
# BadaAircraft: default configuration= departure-ground-run
# BadaAircraft: ===================================================
# BadaAircraft: transition altitude= 24547.67 feet
# AircraftMass ==========================================================
# AircraftMass: set Aircraft Mass= 68000.00 kilograms - Mass= 149914.34 pounds
# AircraftMass ==========================================================
# BadaAircraft: set Cruise FL= 330 - QNH= 999.25 hecto Pascals - computed Altitude MSL=  10058.40 meters
# BadaAircraft====================================================
# BadaAircraft: set target cruise Mach= 0.82
# BadaAircraft====================================================
# AircraftMass ==========================================================
# AircraftMass: set Aircraft Mass= 65803.97 kilograms - Mass= 145072.92 pounds
# AircraftMass ==========================================================
# ['climb-ramp-pt-59-4660.69-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.85-degrees'] 4
# TurnLeg: turn from= 228.05 degrees  to 228.10 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 505.40 knots - radius of turn= 14777.64 meters - radius of turn= 7.98 nautics
# TurnLeg: initial heading= 228.05 degrees
# TurnLeg: final heading= 229.02 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-229.02-degrees - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 10001.53 meters
# GreatCircleRoute: final way-point= TERPO - latitude= 47.34 degrees - longitude= -1.94 degrees - altitudeMSL= 10049.80 meters
# Initial heading degrees: 227.80292016075168 <Home.Guidance.GraphFile.Edge object at 0x7f49e5a92978>
# ['climb-ramp-pt-59-4660.69-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.85-degrees'] 5
# TurnLeg: turn from= 227.80 degrees  to 211.31 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 505.40 knots - radius of turn= 25717.29 meters - radius of turn= 13.89 nautics
# TurnLeg: initial heading= 227.80 degrees
# TurnLeg: final heading= 210.10 degrees
# GreatCircleRoute: initial way-point= turn-pt-32-210.10-degrees - latitude= 47.29 degrees - longitude= -1.99 degrees - altitudeMSL= 10049.80 meters
# GreatCircleRoute: final way-point= ERIGA - latitude= 46.85 degrees - longitude= -2.37 degrees - altitudeMSL= 10049.80 meters
# Initial heading degrees: 209.95240493185077 <Home.Guidance.GraphFile.Edge object at 0x7f49e5bcc8d0>
# ['climb-ramp-pt-59-4660.69-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.85-degrees'] 6
# TurnLeg: turn from= 209.95 degrees  to 218.42 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 505.40 knots - radius of turn= 25717.29 meters - radius of turn= 13.89 nautics
# TurnLeg: initial heading= 209.95 degrees
# TurnLeg: final heading= 218.80 degrees
# GreatCircleRoute: initial way-point= turn-pt-16-218.80-degrees - latitude= 46.83 degrees - longitude= -2.39 degrees - altitudeMSL= 10049.80 meters
# GreatCircleRoute: final way-point= INBAB - latitude= 45.56 degrees - longitude= -3.82 degrees - altitudeMSL= 10049.80 meters
# Initial heading degrees: 217.46342665777826 <Home.Guidance.GraphFile.Edge object at 0x7f49e4a935c0>
# ['climb-ramp-pt-59-4660.69-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.85-degrees'] 7
# TurnLeg: turn from= 217.46 degrees  to 217.36 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 505.40 knots - radius of turn= 25717.29 meters - radius of turn= 13.89 nautics
# TurnLeg: initial heading= 217.46 degrees
# TurnLeg: final heading= 216.91 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-216.91-degrees - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 10049.80 meters
# GreatCircleRoute: final way-point= ATLEN - latitude= 44.50 degrees - longitude= -4.95 degrees - altitudeMSL= 10049.80 meters
# Initial heading degrees: 216.56978637526157 <Home.Guidance.GraphFile.Edge object at 0x7f49e5a821d0>
# ['climb-ramp-pt-59-4660.69-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.85-degrees'] 8
# TurnLeg: turn from= 216.57 degrees  to 218.80 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 505.40 knots - radius of turn= 25717.29 meters - radius of turn= 13.89 nautics
# TurnLeg: initial heading= 216.57 degrees
# TurnLeg: final heading= 219.34 degrees
# GreatCircleRoute: initial way-point= turn-pt-5-219.34-degrees - latitude= 44.50 degrees - longitude= -4.96 degrees - altitudeMSL= 10049.80 meters
# GreatCircleRoute: final way-point= DEVAR - latitude= 43.94 degrees - longitude= -5.58 degrees - altitudeMSL= 10049.80 meters
# Initial heading degrees: 218.38244599530137 <Home.Guidance.GraphFile.Edge object at 0x7f49e5a8d0f0>
# ['climb-ramp-pt-59-4660.69-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.85-degrees'] 9
# TurnLeg: turn from= 218.38 degrees  to 219.20 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 505.40 knots - radius of turn= 25717.29 meters - radius of turn= 13.89 nautics
# TurnLeg: initial heading= 218.38 degrees
# TurnLeg: final heading= 219.49 degrees
# GreatCircleRoute: initial way-point= turn-pt-2-219.49-degrees - latitude= 43.94 degrees - longitude= -5.58 degrees - altitudeMSL= 10049.80 meters
# GreatCircleRoute: final way-point= ASTURIAS - latitude= 43.54 degrees - longitude= -6.02 degrees - altitudeMSL= 10049.80 meters
# Initial heading degrees: 218.90484801107655 <Home.Guidance.GraphFile.Edge object at 0x7f49e5a8ce48>
# ['climb-ramp-pt-59-4660.69-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.85-degrees'] 10
# TurnLeg: turn from= 218.90 degrees  to 206.92 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 505.40 knots - radius of turn= 25717.29 meters - radius of turn= 13.89 nautics
# TurnLeg: initial heading= 218.90 degrees
# TurnLeg: final heading= 206.18 degrees
# GreatCircleRoute: initial way-point= turn-pt-23-206.18-degrees - latitude= 43.51 degrees - longitude= -6.04 degrees - altitudeMSL= 10049.80 meters
# GreatCircleRoute: final way-point= KUVAN - latitude= 43.09 degrees - longitude= -6.33 degrees - altitudeMSL= 10049.80 meters
# Initial heading degrees: 206.0946352676709 <Home.Guidance.GraphFile.Edge object at 0x7f49e5aa71d0>
# ['climb-ramp-pt-59-4660.69-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.85-degrees'] 11
# TurnLeg: turn from= 206.09 degrees  to 207.36 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 505.40 knots - radius of turn= 14777.64 meters - radius of turn= 7.98 nautics
# TurnLeg: initial heading= 206.09 degrees
# TurnLeg: final heading= 208.02 degrees
# GreatCircleRoute: initial way-point= turn-pt-2-208.02-degrees - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 10049.80 meters
# GreatCircleRoute: final way-point= BISMU - latitude= 42.79 degrees - longitude= -6.54 degrees - altitudeMSL= 10049.80 meters
# Initial heading degrees: 207.20836344017573 <Home.Guidance.GraphFile.Edge object at 0x7f49e5c46940>
# ['climb-ramp-pt-59-4660.69-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.85-degrees'] 12
# TurnLeg: turn from= 207.21 degrees  to 206.81 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 505.40 knots - radius of turn= 25717.29 meters - radius of turn= 13.89 nautics
# TurnLeg: initial heading= 207.21 degrees
# TurnLeg: final heading= 206.66 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-206.66-degrees - latitude= 42.79 degrees - longitude= -6.54 degrees - altitudeMSL= 10049.80 meters
# GreatCircleRoute: final way-point= BARKO - latitude= 42.20 degrees - longitude= -6.95 degrees - altitudeMSL= 10049.80 meters
# Initial heading degrees: 206.54414880562737 <Home.Guidance.GraphFile.Edge object at 0x7f49e5c47fd0>
# ['climb-ramp-pt-59-4660.69-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.85-degrees'] 13
# TurnLeg: turn from= 206.54 degrees  to 206.74 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 505.40 knots - radius of turn= 25717.29 meters - radius of turn= 13.89 nautics
# TurnLeg: initial heading= 206.54 degrees
# TurnLeg: final heading= 207.10 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-207.10-degrees - latitude= 42.20 degrees - longitude= -6.95 degrees - altitudeMSL= 10049.80 meters
# BadaAircraft ====================================
# BadaAircraft: entering descent configuration - distance flown 1288545.17 meters - distance flown 695.76 nautics
# BadaAircraft: alt= 10049.80 meters alt= 32971.38 feet
# BadaAircraft: tas= 260.00 m/s - tas= 505.40 knots - cas= 160.41 m/s - cas= 311.82 knots - mach= 0.87
# BadaAircraft: real time = 5752.00 seconds - 1.00 hours 35.00 minutes 52.00 seconds
# BadaAircraft ====================================
# BadaAircraft ====================================
# BadaAircraft: entering approach configuration - distance flown 1505851.72 meters - distance flown 813.09 nautics
# BadaAircraft: alt= 1177.40 meters alt= 3862.81 feet
# BadaAircraft: tas= 57.54 m/s - tas= 111.85 knots - cas= 54.45 m/s - cas= 105.84 knots - mach= 0.17
# BadaAircraft: real time = 7293.00 seconds - 2.00 hours 1.00 minutes 33.00 seconds
# BadaAircraft ====================================
# BadaAircraft: distance to approach fix= 12359.75 meters - delta altitude to approach fix= -504.32 meters
# BadaAircraft ====================================
# BadaAircraft: entering landing configuration - distance flown 1513664.10 meters - distance flown 817.31 nautics
# BadaAircraft: alt= 858.60 meters alt= 2816.88 feet
# BadaAircraft: tas= 53.41 m/s - tas= 103.83 knots - cas= 51.34 m/s - cas= 99.79 knots - mach= 0.16
# BadaAircraft: real time = 7434.00 seconds - 2.00 hours 3.00 minutes 54.00 seconds
# BadaAircraft ====================================
# GreatCircleRoute: final way-point= turn-pt-0-22.85-degrees - latitude= 38.82 degrees - longitude= -9.12 degrees - altitudeMSL= 314.45 meters
# Initial heading degrees: 205.32785242413541 <Home.Guidance.GraphFile.Edge object at 0x7f49e5bd17b8>
# turn-pt-0-22.85-degrees - latitude= 38.82 degrees - longitude= -9.12 degrees - altitudeMSL= 314.45 meters
# TurnLeg: turn from= 205.33 degrees  to 201.99 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 107.19 knots - radius of turn= 3543.04 meters - radius of turn= 1.91 nautics
# TurnLeg: initial heading= 205.33 degrees
# TurnLeg: final heading= 201.94 degrees
# DescentGlideSlope: airport field Elevation Above Sea Level= 114.00 meters
# DescentGlideSlope: distance from RunWay - TouchDown to RunWay - End= 1440.000000000747 meters
# DescentGlideSlope: bearing from touch-down to runway end= 202.00 degrees
# BadaAircraft: distance to runway touch-down= 242.02 meters - delta altitude to runway touch-down= -10.62 meters
# BadaAircraft ====================================
# BadaAircraft: entering arrival-ground-run configuration - distance flown 1530615.20 meters - distance flown 826.47 nautics
# BadaAircraft: alt= 114.61 meters alt= 376.03 feet
# BadaAircraft: tas= 44.79 m/s - tas= 87.07 knots - cas= 44.56 m/s - cas= 86.62 knots - mach= 0.13
# BadaAircraft: real time = 7777.40 seconds - 2.00 hours 9.00 minutes 37.40 seconds
# BadaAircraft ====================================
# GroundRunLeg: ground run - run-way true heading= 22.0 degrees
# BadaAircraft: taxi speed reached => end of simulation

# %%
updateFlightPath.simulateFly(4, strRoute)
# Out:
# WayPointsDatabase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# WayPointsDatabase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/WayPoints.xls
# AirportsDatabase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# AirportsDatabase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/Airports.csv
# RunWayDataBase: file folder= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment
# RunWayDataBase: file path= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/RunWays.xls
# /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/Environment/RunWays.xls
# BadaAircraftDatabase: aircraft= A320 exists= True
# BadaAircraftDatabase: aircraft= A320 - found in database
# BadaAircraftDatabase: aircraft= A320 - OPF file= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/../Bada381DataFiles/A320__.OPF - exists= True
# BadaAircraft: Wing Area Surface= 122.6 Square-Meters
# BadaAircraft: stall speed= {'CR': 145.0, 'IC': 120.0, 'TO': 114.0, 'AP': 107.0, 'LD': 101.0} knots
# AircraftMass: aircraft reference mass= 64000.00 kilograms
# AircraftMass: aircraft minimum mass= 39000.00 kilograms
# AircraftMass: aircraft maximum mass= 77000.00 kilograms
# AircraftMass: aircraft maximum pay load mass= 21500.00 kilograms
# BadaAircraft: ===================================================
# BadaAircraft: default configuration= departure-ground-run
# BadaAircraft: ===================================================
# BadaAircraft: transition altitude= 24547.67 feet
# AircraftMass ==========================================================
# AircraftMass: set Aircraft Mass= 68000.00 kilograms - Mass= 149914.34 pounds
# AircraftMass ==========================================================
# BadaAircraft: set Cruise FL= 330 - QNH= 999.25 hecto Pascals - computed Altitude MSL=  10058.40 meters
# BadaAircraft====================================================
# BadaAircraft: set target cruise Mach= 0.82
# BadaAircraft====================================================
# GroundRunLeg: ground run - run-way true heading= 265.0 degrees
# GroundRunLeg: V stall Calibrated AirSpeed= 117.51 knots
# BadaAircraft: TAS= 143.93 knots - CAS= 143.17 knots > (1.2 * V CAS stall)= 140.94 knots
# BadaAircraft ====================================
# BadaAircraft: entering take-off configuration - distance flown 1667.38 meters - distance flown 0.90 nautics
# BadaAircraft: alt= 119.48 meters alt= 392.00 feet
# BadaAircraft: tas= 72.53 m/s - tas= 141.00 knots - cas= 72.15 m/s - cas= 140.25 knots - mach= 0.21
# BadaAircraft: real time = 45.00 seconds - 0.00 hours 0.00 minutes 45.00 seconds
# BadaAircraft ====================================
# ClimbRamp: run-way orientation degrees= 265.0 degrees
# BadaAircraft: CAS= 145.24 knots >= Initial Climb Stall Speed= 123.62 knots
# BadaAircraft ====================================
# BadaAircraft: entering initial-climb configuration - distance flown 2187.44 meters - distance flown 1.18 nautics
# BadaAircraft: alt= 165.85 meters alt= 544.12 feet
# BadaAircraft: tas= 75.12 m/s - tas= 146.02 knots - cas= 74.57 m/s - cas= 144.95 knots - mach= 0.22
# BadaAircraft: real time = 52.00 seconds - 0.00 hours 0.00 minutes 52.00 seconds
# BadaAircraft ====================================
# GroundRunLeg: ground run - run-way true heading= 22.0 degrees
# ArrivalRunWayTouchDownConstraint: add touch down constraint= Lisbon-Lisboa-Rwy-03-touch-down - latitude= 38.78 degrees - longitude= -9.14 degrees - altitudeMSL= 114.00 meters
# DescentGlideSlope: airport field Elevation Above Sea Level= 114.00 meters
# DescentGlideSlope: distance from RunWay - TouchDown to RunWay - End= 1440.000000000747 meters
# DescentGlideSlope: bearing from touch-down to runway end= 202.00 degrees
# DescentGlideSlope: glide slope Length= 2416.5938382364625  meters
# DescentGlideSlope: glide slope orientation= 22.0 degrees
# DescentGlideSlope: distance from last way point to touch-down: 1.32 nautics
# TurnLeg: turn from= 22.00 degrees  to 22.02 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 111.47 knots - radius of turn= 3831.57 meters - radius of turn= 2.07 nautics
# TurnLeg: initial heading= 22.00 degrees
# TargetApproachConstraint: add target approach way point constraint= turn-pt-0-22.86-degrees - latitude= 38.80 degrees - longitude= -9.13 degrees - altitudeMSL= 241.91 meters
# BadaAircraftDatabase: aircraft= A320 exists= True
# BadaAircraftDatabase: aircraft= A320 - found in database
# BadaAircraftDatabase: aircraft= A320 - OPF file= /home/tanthm/git/AircraftTrajectoryPredictor/FlightDynamics/Home/BadaAircraftPerformance/../Bada381DataFiles/A320__.OPF - exists= True
# BadaAircraft: Wing Area Surface= 122.6 Square-Meters
# BadaAircraft: stall speed= {'CR': 145.0, 'IC': 120.0, 'TO': 114.0, 'AP': 107.0, 'LD': 101.0} knots
# AircraftMass: aircraft reference mass= 64000.00 kilograms
# AircraftMass: aircraft minimum mass= 39000.00 kilograms
# AircraftMass: aircraft maximum mass= 77000.00 kilograms
# AircraftMass: aircraft maximum pay load mass= 21500.00 kilograms
# BadaAircraft: ===================================================
# BadaAircraft: default configuration= departure-ground-run
# BadaAircraft: ===================================================
# BadaAircraft: transition altitude= 24547.67 feet
# AircraftMass ==========================================================
# AircraftMass: set Aircraft Mass= 68000.00 kilograms - Mass= 149914.34 pounds
# AircraftMass ==========================================================
# BadaAircraft: set Cruise FL= 330 - QNH= 999.25 hecto Pascals - computed Altitude MSL=  10058.40 meters
# BadaAircraft====================================================
# BadaAircraft: set target cruise Mach= 0.82
# BadaAircraft====================================================
# AircraftMass ==========================================================
# AircraftMass: set Aircraft Mass= 65803.97 kilograms - Mass= 145072.92 pounds
# AircraftMass ==========================================================
# ['climb-ramp-pt-31-2371.49-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.86-degrees'] 4
# TurnLeg: turn from= 228.05 degrees  to 228.10 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 13156.80 meters - radius of turn= 7.10 nautics
# TurnLeg: initial heading= 228.05 degrees
# TurnLeg: final heading= 229.07 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-229.07-degrees - latitude= 47.60 degrees - longitude= -1.52 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= TERPO - latitude= 47.35 degrees - longitude= -1.93 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 227.80312239481418 <Home.Guidance.GraphFile.Edge object at 0x7f49e5c57b38>
# ['climb-ramp-pt-31-2371.49-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.86-degrees'] 5
# TurnLeg: turn from= 227.80 degrees  to 211.31 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 227.80 degrees
# TurnLeg: final heading= 210.26 degrees
# GreatCircleRoute: initial way-point= turn-pt-30-210.26-degrees - latitude= 47.30 degrees - longitude= -1.99 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= ERIGA - latitude= 46.85 degrees - longitude= -2.37 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 210.08051087623033 <Home.Guidance.GraphFile.Edge object at 0x7f49e4b93d68>
# ['climb-ramp-pt-31-2371.49-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.86-degrees'] 6
# TurnLeg: turn from= 210.08 degrees  to 218.42 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 210.08 degrees
# TurnLeg: final heading= 218.85 degrees
# GreatCircleRoute: initial way-point= turn-pt-15-218.85-degrees - latitude= 46.83 degrees - longitude= -2.39 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= INBAB - latitude= 45.56 degrees - longitude= -3.83 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 217.44688731354728 <Home.Guidance.GraphFile.Edge object at 0x7f49e61e7d68>
# ['climb-ramp-pt-31-2371.49-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.86-degrees'] 7
# TurnLeg: turn from= 217.45 degrees  to 217.36 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 217.45 degrees
# TurnLeg: final heading= 216.86 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-216.86-degrees - latitude= 45.57 degrees - longitude= -3.81 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= ATLEN - latitude= 44.50 degrees - longitude= -4.95 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 216.56626334057745 <Home.Guidance.GraphFile.Edge object at 0x7f49e617fd68>
# ['climb-ramp-pt-31-2371.49-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.86-degrees'] 8
# TurnLeg: turn from= 216.57 degrees  to 218.80 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 216.57 degrees
# TurnLeg: final heading= 218.91 degrees
# GreatCircleRoute: initial way-point= turn-pt-4-218.91-degrees - latitude= 44.50 degrees - longitude= -4.95 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= DEVAR - latitude= 43.94 degrees - longitude= -5.58 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 218.38357794793163 <Home.Guidance.GraphFile.Edge object at 0x7f4a18357eb8>
# ['climb-ramp-pt-31-2371.49-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.86-degrees'] 9
# TurnLeg: turn from= 218.38 degrees  to 219.20 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 218.38 degrees
# TurnLeg: final heading= 219.55 degrees
# GreatCircleRoute: initial way-point= turn-pt-2-219.55-degrees - latitude= 43.94 degrees - longitude= -5.58 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= ASTURIAS - latitude= 43.55 degrees - longitude= -6.01 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 218.90938379984297 <Home.Guidance.GraphFile.Edge object at 0x7f49e4a140b8>
# ['climb-ramp-pt-31-2371.49-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.86-degrees'] 10
# TurnLeg: turn from= 218.91 degrees  to 206.92 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 218.91 degrees
# TurnLeg: final heading= 206.05 degrees
# GreatCircleRoute: initial way-point= turn-pt-22-206.05-degrees - latitude= 43.52 degrees - longitude= -6.04 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= KUVAN - latitude= 43.10 degrees - longitude= -6.32 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 206.17449292519288 <Home.Guidance.GraphFile.Edge object at 0x7f49e5a9cc88>
# ['climb-ramp-pt-31-2371.49-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.86-degrees'] 11
# TurnLeg: turn from= 206.17 degrees  to 207.36 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 13156.80 meters - radius of turn= 7.10 nautics
# TurnLeg: initial heading= 206.17 degrees
# TurnLeg: final heading= 208.21 degrees
# GreatCircleRoute: initial way-point= turn-pt-2-208.21-degrees - latitude= 43.11 degrees - longitude= -6.32 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= BISMU - latitude= 42.79 degrees - longitude= -6.54 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 207.20615441914697 <Home.Guidance.GraphFile.Edge object at 0x7f49e5a8b2b0>
# ['climb-ramp-pt-31-2371.49-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.86-degrees'] 12
# TurnLeg: turn from= 207.21 degrees  to 206.81 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 207.21 degrees
# TurnLeg: final heading= 206.62 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-206.62-degrees - latitude= 42.79 degrees - longitude= -6.54 degrees - altitudeMSL= 10050.12 meters
# GreatCircleRoute: final way-point= BARKO - latitude= 42.19 degrees - longitude= -6.95 degrees - altitudeMSL= 10050.12 meters
# Initial heading degrees: 206.54275400780782 <Home.Guidance.GraphFile.Edge object at 0x7f49e5c1ccc0>
# ['climb-ramp-pt-31-2371.49-meters', 'LAIGLE', 'ROLEN', 'PEPON', 'KURIS', 'TERPO', 'ERIGA', 'INBAB', 'ATLEN', 'DEVAR', 'ASTURIAS', 'KUVAN', 'BISMU', 'BARKO', 'turn-pt-0-22.86-degrees'] 13
# TurnLeg: turn from= 206.54 degrees  to 206.72 degrees - turn step is= 3.00 degrees
# TurnLeg: tas= 476.88 knots - radius of turn= 22896.56 meters - radius of turn= 12.36 nautics
# TurnLeg: initial heading= 206.54 degrees
# TurnLeg: final heading= 207.13 degrees
# GreatCircleRoute: initial way-point= turn-pt-1-207.13-degrees - latitude= 42.20 degrees - longitude= -6.95 degrees - altitudeMSL= 10050.12 meters
# BadaAircraft ====================================
# BadaAircraft: entering descent configuration - distance flown 1300060.19 meters - distance flown 701.98 nautics
# BadaAircraft: alt= 10050.12 meters alt= 32972.42 feet
# BadaAircraft: tas= 245.33 m/s - tas= 476.88 knots - cas= 150.36 m/s - cas= 292.28 knots - mach= 0.82
# BadaAircraft: real time = 6037.00 seconds - 1.00 hours 40.00 minutes 37.00 seconds
# BadaAircraft ====================================
# BadaAircraft ====================================
# BadaAircraft: entering approach configuration - distance flown 1506772.91 meters - distance flown 813.59 nautics
# BadaAircraft: alt= 1116.11 meters alt= 3661.72 feet
# BadaAircraft: tas= 57.38 m/s - tas= 111.54 knots - cas= 54.47 m/s - cas= 105.87 knots - mach= 0.17
# BadaAircraft: real time = 7557.00 seconds - 2.00 hours 5.00 minutes 57.00 seconds
# BadaAircraft ====================================
# BadaAircraft: distance to approach fix= 12501.86 meters - delta altitude to approach fix= -540.37 meters
# BadaAircraft ====================================
# BadaAircraft: entering landing configuration - distance flown 1514726.83 meters - distance flown 817.89 nautics
# BadaAircraft: alt= 772.28 meters alt= 2533.70 feet
# BadaAircraft: tas= 53.23 m/s - tas= 103.47 knots - cas= 51.37 m/s - cas= 99.86 knots - mach= 0.16
# BadaAircraft: real time = 7701.00 seconds - 2.00 hours 8.00 minutes 21.00 seconds
# BadaAircraft ====================================
# GreatCircleRoute: final way-point= turn-pt-0-22.86-degrees - latitude= 38.80 degrees - longitude= -9.13 degrees - altitudeMSL= 213.75 meters
# Initial heading degrees: 205.30313796774516 <Home.Guidance.GraphFile.Edge object at 0x7f49e774bc18>
# turn-pt-0-22.86-degrees - latitude= 38.80 degrees - longitude= -9.13 degrees - altitudeMSL= 213.75 meters
# TurnLeg: turn from= 205.30 degrees  to 201.98 degrees - turn step is= -3.00 degrees
# TurnLeg: tas= 106.73 knots - radius of turn= 3512.86 meters - radius of turn= 1.90 nautics
# TurnLeg: initial heading= 205.30 degrees
# TurnLeg: final heading= 201.97 degrees
# DescentGlideSlope: airport field Elevation Above Sea Level= 114.00 meters
# DescentGlideSlope: distance from RunWay - TouchDown to RunWay - End= 1440.000000000747 meters
# DescentGlideSlope: bearing from touch-down to runway end= 202.00 degrees
# BadaAircraft: distance to runway touch-down= 254.54 meters - delta altitude to runway touch-down= -11.33 meters
# BadaAircraft ====================================
# BadaAircraft: entering arrival-ground-run configuration - distance flown 1529472.42 meters - distance flown 825.85 nautics
# BadaAircraft: alt= 115.33 meters alt= 378.37 feet
# BadaAircraft: tas= 44.86 m/s - tas= 87.20 knots - cas= 44.63 m/s - cas= 86.75 knots - mach= 0.13
# BadaAircraft: real time = 8000.40 seconds - 2.00 hours 13.00 minutes 20.40 seconds
# BadaAircraft ====================================
# GroundRunLeg: ground run - run-way true heading= 22.0 degrees
# BadaAircraft: taxi speed reached => end of simulation
